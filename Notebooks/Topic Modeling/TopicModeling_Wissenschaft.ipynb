# %% [markdown]
# ## Topic Modeling - Wissenschaft-Datensatz

# %%
# !pip install bertopic

# %%
from bertopic import BERTopic

import pandas as pd
import re

import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')

from sklearn.feature_extraction.text import CountVectorizer
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# ### Daten einlesen & Preprocessing

# %%
df = pd.read_excel('tweets_wissenschaft.xlsx')

# %%
df['tweet_text'] = df['tweet_text'].astype(str)
df['retweet_text_retweeted_tweet'] = df['retweet_text_retweeted_tweet'].astype(str)
df['zitat_text'] = df['zitat_text'].astype(str)

# %%
def classify_tweet(row):
    if row['tweet_text'] != '-998' and row['retweet_text_retweeted_tweet'] == '-998' and row['zitat_text'] == '-998':
        return 'tweet'
    elif row['retweet_text_retweeted_tweet'] != '-998':
        return 'retweet'
    elif row['tweet_text'] != '-998' and row['zitat_text'] != '-998':
        return 'zitat_tweet'
    return 'unclassified'

# %%
df['tweet_class'] = df.apply(classify_tweet, axis=1)

# %%
def gather_texts(row):
    texts = []
    for column in ['tweet_text', 'retweet_text_retweeted_tweet', 'zitat_text']:
      if pd.notna(row[column]) and str(row[column]) != '-998':
            texts.append(row[column])
    return ' '.join(texts)

# %%
df['all_tweets'] = df.apply(gather_texts, axis=1)

# %%
def preprocess_tweet(text):
    text = re.sub(r'@\w+', '', text)  # Entfernt Benutzernamen
    text = re.sub(r'http\S+', '', text)  # Entfernt URLs
    text = re.sub(r'www.\S+', '', text)  # Entfernt URLs
    text = re.sub(r'[0-9]+', '', text)  # Entfernt Zahlen
    text = re.sub(r'[^\w\s]', '', text)  # Entfernt Sonderzeichen
    text = re.sub(r'_', '', text)  # Entfernt Unterstriche
    text = re.sub(r'\s+', ' ', text).strip()  # Ersetzt mehrere Leerzeichen durch ein einzelnes und entfernt sie am Anfang/Ende
    text = re.sub(r'-998', '', text)  # entfernt fehlende Werte
    text = re.sub(r'nan', '', text)  # entfernt fehlende Werte

    return text

# %%
df['all_tweets'] = df['all_tweets'].apply(preprocess_tweet)

# %% [markdown]
# ### Topic Modeling mit BERTopic

# %%
docs = list(df.all_tweets.values)

german_stopwords = set(stopwords.words('german'))
stopwords = list(german_stopwords)
vectorizer_model = CountVectorizer(stop_words=stopwords)

# %%
len(docs)
# Out:
# 3749

# %% [markdown]
# #### Erstes Modell ohne Beschränkung der Themenanzahl

# %%
# BERTopic-Modell erstellen
model = BERTopic(language="German", calculate_probabilities=True, verbose=True, vectorizer_model=vectorizer_model)

# Model anwenden und Topics extrahieren
topics, probs = model.fit_transform(docs)
# Out:
# 2024-04-29 11:35:43,291 - BERTopic - Embedding - Transforming documents to embeddings.
# Batches:   0%|          | 0/118 [00:00<?, ?it/s]
# 2024-04-29 11:35:54,121 - BERTopic - Embedding - Completed ✓
# 2024-04-29 11:35:54,127 - BERTopic - Dimensionality - Fitting the dimensionality reduction algorithm
# 2024-04-29 11:36:26,285 - BERTopic - Dimensionality - Completed ✓
# 2024-04-29 11:36:26,287 - BERTopic - Cluster - Start clustering the reduced embeddings
# 2024-04-29 11:36:28,090 - BERTopic - Cluster - Completed ✓
# 2024-04-29 11:36:28,097 - BERTopic - Representation - Extracting topics from clusters using representation models.
# 2024-04-29 11:36:28,549 - BERTopic - Representation - Completed ✓

# %%
# Ergebnisse
print(f"Anzahl der Topics: {model.get_topic_info().shape[0] - 1}")  # Minus 1 wegen des Outliers-Topics (-1)
topic_info = model.get_topic_info()
topic_info.head(20)
# Out:
# Anzahl der Topics: 101
#     Topic  Count                                               Name  \
# 0      -1   1121                       -1_forschung_heute_gute_gibt
# 1       0    222                      0_forschung_ja_freiheit_immer
# 2       1    129       1_deutschland_deutsche_deutschen_beschlossen
# 3       2    110      2_mecfs_versorgung_longcovid_mecfsimbundestag
# 4       3     63                  3_desamfornet_medizin_klinik_data
# 5       4     51  4_digitalen_digitalisierung_transformation_cyb...
# 6       5     45           5_politiksprüche_zib_verbote_verzweifeln
# 7       6     42       6_ausgezeichnet_gratulieren_award_leistungen
# 8       7     41            7_archäologie_germanen_meldungen_kultur
# 9       8     39  8_genderstudies_personen_reagierst_nervtötendster
# 10      9     38             9_alternative_akutheit_energiekrise_ee
# 11     10     38  10_ichbinhanna_ichbinreyhan_wegen_arbeitsbedin...
# 12     11     37     11_käthe_jüdin_leichterstaatspreis_ravensbrück
# 13     12     36   12_frauen_mädchen_womeninscience_internationalen
# 14     13     36  13_tumorerkrankungen_nationalen_krebs_krebsfor...
# 15     14     36                   14_wieler_dankewieler_lothar_rki
# 16     15     35                      15_longcovid_covid_long_mecfs
# 17     16     35           16_gene_albrechtthaerweg_rundgang_spuren
# 18     17     33                  17_kernfusion_usa_belogen_getarnt
# 19     18     33  18_empfehlenswerter_beitrag_lehre_leibnizinfor...
#
#                                        Representation  \
# 0   [forschung, heute, gute, gibt, innovation, mac...
# 1   [forschung, ja, freiheit, immer, gibt, einfach...
# 2   [deutschland, deutsche, deutschen, beschlossen...
# 3   [mecfs, versorgung, longcovid, mecfsimbundesta...
# 4   [desamfornet, medizin, klinik, data, mitmachen...
# 5   [digitalen, digitalisierung, transformation, c...
# 6   [politiksprüche, zib, verbote, verzweifeln, um...
# 7   [ausgezeichnet, gratulieren, award, leistungen...
# 8   [archäologie, germanen, meldungen, kultur, nac...
# 9   [genderstudies, personen, reagierst, nervtöten...
# 10  [alternative, akutheit, energiekrise, ee, redu...
# 11  [ichbinhanna, ichbinreyhan, wegen, arbeitsbedi...
# 12  [käthe, jüdin, leichterstaatspreis, ravensbrüc...
# 13  [frauen, mädchen, womeninscience, internationa...
# 14  [tumorerkrankungen, nationalen, krebs, krebsfo...
# 15  [wieler, dankewieler, lothar, rki, amt, widmen...
# 16  [longcovid, covid, long, mecfs, identifiziert,...
# 17  [gene, albrechtthaerweg, rundgang, spuren, pfl...
# 18  [kernfusion, usa, belogen, getarnt, kernwaffen...
# 19  [empfehlenswerter, beitrag, lehre, leibnizinfo...
#
#                                   Representative_Docs
# 0   [NATURE beklagt den Rückgang innovativer Forsc...
# 1   [Eigentlich geht das ganz einfach Es muß etwas...
# 2   [Deutschland wird jetzt schneller und innovati...
# 3   [Heute stille Visualisierung vor dem Bundestag...
# 4   [Brücken zwischen Forschung und Klinik stärken...
# 5   [Die stärkt Forschung und Lehre zur digitalen ...
# 6   [Immer wieder dieselben Politiksprüche beim Kl...
# 7   [Für seine Leistungen im Bereich der Forschung...
# 8   [Waren die Germanen nur raubeinige Barbaren Di...
# 9   [Wenn du über Jahre ach was Jahrzehnte in nerv...
# 10  [Und was ist die Alternative in der Akutheit d...
# 11  [Ihr kennt diesen Spruch Menschen kommen wegen...
# 12  [Es ist nur eine Nebenepisode aber symbolpolit...
# 13  [Warum ist es toll eine Forscherin und Teil de...
# 14  [Die Universitätsklinika Essen und Köln werden...
# 15  [Schade aber nachvollziehbar Danke DankeWieler...
# 16  [Long Covid Forschung identifiziert Hauptursac...
# 17  [Seit Jahren werden auf dem Campus der die Gen...
# 18  [Krass wie die Öffentlichkeit rund um dieses F...
# 19  [Empfehlenswerter Beitrag von Forschung und Le...

# %%
model.visualize_topics()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="4fcdc6d4-e9d9-4745-be96-e85a49c2d58a" class="plotly-graph-div" style="height:650px; width:650px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4fcdc6d4-e9d9-4745-be96-e85a49c2d58a")) {                    Plotly.newPlot(                        "4fcdc6d4-e9d9-4745-be96-e85a49c2d58a",                        [{"customdata":[[0,"forschung | ja | freiheit | immer | gibt",222],[1,"deutschland | deutsche | deutschen | beschlossen | schnelleren",129],[2,"mecfs | versorgung | longcovid | mecfsimbundestag | brauchen",110],[3,"desamfornet | medizin | klinik | data | mitmachen",63],[4,"digitalen | digitalisierung | transformation | cybersicherheit | dsi",51],[5,"politikspr\u00fcche | zib | verbote | verzweifeln | umsetzen",45],[6,"ausgezeichnet | gratulieren | award | leistungen | sossalla",42],[7,"arch\u00e4ologie | germanen | meldungen | kultur | nachrichten",41],[8,"genderstudies | personen | reagierst | nervt\u00f6tendster | behauptungen",39],[9,"alternative | akutheit | energiekrise | ee | reduzieren",38],[10,"ichbinhanna | ichbinreyhan | wegen | arbeitsbedingungen | bedingungen",38],[11,"k\u00e4the | j\u00fcdin | leichterstaatspreis | ravensbr\u00fcck | sozialdemokratin",37],[12,"frauen | m\u00e4dchen | womeninscience | internationalen | tag",36],[13,"tumorerkrankungen | nationalen | krebs | krebsforschung | nct",36],[14,"wieler | dankewieler | lothar | rki | amt",36],[15,"longcovid | covid | long | mecfs | identifiziert",35],[16,"gene | albrechtthaerweg | rundgang | spuren | pflanzen",35],[17,"kernfusion | usa | belogen | getarnt | kernwaffenteststoppvertrag",33],[18,"empfehlenswerter | beitrag | lehre | leibnizinformationszentrum | forschungsmethoden",33],[19,"abkommen | halbiert | eeausbau | pariser | einzuhalten",33],[20,"mobilit\u00e4t | verkehr | niedriger | stra\u00dfen | sozio\u00f6konomischer",31],[21,"wasserstoff | made | cdu | brennst\u00e4ben | czaja",30],[22,"ki | k\u00fcnstlicheintelligenz | intelligenz | ai | k\u00fcnstliche",30],[23,"bev\u00f6lkerungsschutz | fachkongress | foreign | policy | lab",30],[24,"podcast | podcasts | brpodcast | berlin | science",30],[25,"chatgpt | langfristig | lehre | gpt | sprachmodelle",29],[26,"wirberlin | istberlin | wusstet | heimatort | brain",28],[27,"hei\u00dft | endemie | erreger | endemisch | respiratorischen",28],[28,"z\u00f6gern | technologieoffenheit | chancen | ergreifen | enorme",28],[29,"immunschw\u00e4che | virusreservoir | autoimmunit\u00e4t | reaktivierung | chronische",27],[30,"ehub | fellow | resilienz | lesetippausf\u00fchrlicher | keilschriftfragmente",27],[31,"antibiotika | sciencepodcast | gehirns | infektionsimmunologie | tiho",26],[32,"ukraine | minister | bremen | russland | treffen",25],[33,"qualitativen | langzeitperspektiven | tagung | sozialforschung | einreichungen",25],[34,"pfizers | malone | bots | mrnapionier | l\u00f6schungen",25],[35,"vbrick | videoplattform | korpusanalyse | pr\u00fcfungen | werkzeuge",23],[36,"eitelkeit | fall | fokussiert | irgendwie | ja",23],[37,"ministerin | bildung | b\u00fccher | w\u00e4lzen | bibliotheken",23],[38,"unm\u00f6glich | menschenfeindlichkeit | bautzen | verk\u00fcrzung | verharmlosen",23],[39,"behaviour | planetary | verhalten | gerald | gr\u00fcndungsdirektorin",22],[40,"duz | europaweit | special | spitze | berlinuniversityalliance",22],[41,"fdm | forschungsdatenmanagement | reputation | nachpr\u00fcfbar | eigenst\u00e4ndige",22],[42,"einstein | stiftung | globalhealth | internationale | einsteinstelltein",22],[43,"stream | anmeldeformular | dresden | spread | meldet",22],[44,"keppler | k\u00fcnftiger | sciencetalks | prof | pandemien",21],[45,"job | bewerben | promotionsstelle | jobangebot | \u00f6ffentlichkeitsarbeit",21],[46,"optimal | wissenschaftssystem | ...

# %% [markdown]
# #### Reduzierung der Themenanzahl

# %%
model.reduce_topics(docs, nr_topics=30)
# Out:
# 2024-04-29 11:36:30,627 - BERTopic - Topic reduction - Reducing number of topics
# 2024-04-29 11:36:30,965 - BERTopic - Topic reduction - Reduced number of topics from 102 to 30

# %%
# Ergebnisse
print(f"Anzahl der Topics: {model.get_topic_info().shape[0] - 1}")  # Minus 1 wegen des Outliers-Topics (-1)
topic_info_reduced = model.get_topic_info()
topic_info_reduced
# Out:
# Anzahl der Topics: 29
#     Topic  Count                                               Name  \
# 0      -1   1121                       -1_forschung_heute_gibt_mehr
# 1       0    736         0_forschung_ichbinhanna_wissenschaft_lehre
# 2       1    328                     1_forschung_digitale_the_lehre
# 3       2    294      2_mecfs_versorgung_mecfsimbundestag_forschung
# 4       3    164             3_berlin_freuen_bewerbungen_exzellente
# 5       4    141                      4_heißt_longcovid_covid_viren
# 6       5    120       5_kernfusion_wasserstoff_alternative_energie
# 7       6    113                       6_geht_klima_engagiert_ehren
# 8       7    106  7_frauen_genderstudies_mädchen_wissenschaftler...
# 9       8     84           8_käthe_ukraine_film_leichterstaatspreis
# 10      9     67                    9_lothar_wieler_dankewieler_rki
# 11     10     66         10_pflanzen_albrechtthaerweg_rundgang_gene
# 12     11     53           11_archäologie_germanen_kultur_meldungen
# 13     12     37         12_pfizers_gofforschung_malone_übersetzung
# 14     13     31             13_mobilität_niedriger_verkehr_straßen
# 15     14     30  14_kindertagesbetreuung_gewalt_forschungsethik...
# 16     15     30                      15_phdlife_phd_hast_christmas
# 17     16     29  16_psychotherapie_verfahren_allgemeinverständl...
# 18     17     24  17_stellenausschreibung_bewerbungsfrist_profes...
# 19     18     22     18_stream_anmeldeformular_tiktoktagung_dresden
# 20     19     20               19_jahr_weihnachten_wünschen_schenke
# 21     20     20           20_mal_entscheidenden_helfe_gofforschung
# 22     21     19             21_tiere_tierversuche_wurden_gezüchtet
# 23     22     15  22_staatssekretärin_bundesministerium_bielefel...
# 24     23     15  23_ufoforschung_update_ifouniversität_flugobjekte
# 25     24     14  24_stressoren_stärkste_resilienzcoachings_arbe...
# 26     25     14                              25_quem_está_ano_este
# 27     26     12  26_verbot_gainoffunctionforschung_maskenpflich...
# 28     27     12  27_tagungshomepage_checkt_memefication_perform...
# 29     28     12      28_fleisch_adipositas_fleischkonsum_ernährung
#
#                                        Representation  \
# 0   [forschung, heute, gibt, mehr, gute, innovatio...
# 1   [forschung, ichbinhanna, wissenschaft, lehre, ...
# 2   [forschung, digitale, the, lehre, thema, chatg...
# 3   [mecfs, versorgung, mecfsimbundestag, forschun...
# 4   [berlin, freuen, bewerbungen, exzellente, heim...
# 5   [heißt, longcovid, covid, viren, prävention, e...
# 6   [kernfusion, wasserstoff, alternative, energie...
# 7   [geht, klima, engagiert, ehren, fleissig, klim...
# 8   [frauen, genderstudies, mädchen, wissenschaftl...
# 9   [käthe, ukraine, film, leichterstaatspreis, jü...
# 10  [lothar, wieler, dankewieler, rki, amt, verläs...
# 11  [pflanzen, albrechtthaerweg, rundgang, gene, s...
# 12  [archäologie, germanen, kultur, meldungen, akt...
# 13  [pfizers, gofforschung, malone, übersetzung, e...
# 14  [mobilität, niedriger, verkehr, straßen, sozio...
# 15  [kindertagesbetreuung, gewalt, forschungsethik...
# 16  [phdlife, phd, hast, christmas, kindergrundsic...
# 17  [psychotherapie, verfahren, allgemeinverständl...
# 18  [stellenausschreibung, bewerbungsfrist, profes...
# 19  [stream, anmeldeformular, tiktoktagung, dresde...
# 20  [jahr, weihnachten, wünschen, schenke, geformt...
# 21  [mal, entscheidenden, helfe, gofforschung, bes...
# 22  [tiere, tierversuche, wurden, gezüchtet, getöt...
# 23  [staatssekretärin, bundesministerium, bielefel...
# 24  [ufoforschung, update, ifouniversität, flugobj...
# 25  [stressoren, stärkste, resilienzcoachings, arb...
# 26  [quem, está, ano, este, wer, mais, por, assumi...
# 27  [verbot, gainoffunctionforschung, maskenpflich...
# 28  [tagungshomepage, checkt, memefication, perfor...
# 29  [fleisch, adipositas, fleischkonsum, ernährung...
#
#                                   Representative_Docs
# 0   [Jeden Tag kommen so unglaublich viele spannen...
# 1   [Immer wieder dieselben Politiksprüche beim Kl...
# 2   [Auch in dieser Woche bieten wir Ihnen wieder ...
# 3   [MECFSimBundestag Heute nach Jahrzehnten ohne ...
# 4   [Wusstet ihr dass Berlin DER Heimatort von Wis...
# 5   [Endemie heißt nicht dass ein Erreger harmlos ...
# 6   [Und was ist die Alternative in der Akutheit d...
# 7   [Manche Menschen verstehen einfach nicht was d...
# 8   [Wenn du über Jahre ach was Jahrzehnte in nerv...
# 9   [Es ist nur eine Nebenepisode aber symbolpolit...
# 10  [Professor Lothar H Wieler verlässt das RKI Er...
# 11  [Seit Jahren werden auf dem Campus der die Gen...
# 12  [Rituale in der Bronzezeit Wunschbrunnen in Ba...
# 13  [Sonntagskrimi Legen Sie ihn weg das hier ist ...
# 14  [Wissing Neue Straßen sorgen nicht für mehr Ve...
# 15  [Und Österreich Wie schaut es bei uns aus Laut...
# 16  [Hast du Spaß am Programmieren und Erfahrung m...
# 17  [Wir haben eine neue Podcastreihe In TIEFENFUN...
# 18  [Stellenausschreibung An meiner Professur an d...
# 19  [Spread the News Die Anmeldung zu unserer TikT...
# 20  [Zu Weihnachten schenke ich euch das am besten...
# 21  [Guten Morgen Was war gestern schön was hat eu...
# 22  [Wir haben heute ein neues Factsheet über Tier...
# 23  [Profin Dr Angelika Epple wird neue Rektorin d...
# 24  [UFOForschung BreakingNews Weitere Flugobjekte...
# 25  [Es stellt sich die Fragewie Hochschulen resil...
# 26  [Matéria na Portadores de esperança para Dez p...
# 27  [Im Jahr hat in insgesamt Tweets LongCovid the...
# 28  [Unsere Tagungshomepage für die TikTokTagung M...
# 29  [Meine kleine Tochter hat einen kürzlich erfor...

# %%
for i in range(1, 11):
    representation = topic_info_reduced.loc[i, 'Representation']
    representative_docs = topic_info_reduced.loc[i, 'Representative_Docs']
    print(f"Thema {i}:")
    print(f"Representation: {representation}")
    print(f"Representative_Docs: {representative_docs}")
    print()
# Out:
# Thema 1:
# Representation: ['forschung', 'ichbinhanna', 'wissenschaft', 'lehre', 'immer', 'ja', 'mehr', 'deutschland', 'gibt', 'ermöglicht']
# Representative_Docs: ['Immer wieder dieselben Politiksprüche beim Klima Auf Forschung setzen nicht auf Verbote Es ist zum Verzweifeln Ja Mehr Forschung ist toll Aber gleichzeitig müssen wir JETZT umsetzen was die Forschung der letzten Jahrzehnte uns heute ermöglicht Und das ist viel zib', 'Immer wieder dieselben Politiksprüche beim Klima Auf Forschung setzen nicht auf Verbote Es ist zum Verzweifeln Ja Mehr Forschung ist toll Aber gleichzeitig müssen wir JETZT umsetzen was die Forschung der letzten Jahrzehnte uns heute ermöglicht Und das ist viel zib', 'Immer wieder dieselben Politiksprüche beim Klima Auf Forschung setzen nicht auf Verbote Es ist zum Verzweifeln Ja Mehr Forschung ist toll Aber gleichzeitig müssen wir JETZT umsetzen was die Forschung der letzten Jahrzehnte uns heute ermöglicht Und das ist viel zib']
#
# Thema 2:
# Representation: ['forschung', 'digitale', 'the', 'lehre', 'thema', 'chatgpt', 'digitalen', 'podcast', 'fdm', 'digitalisierung']
# Representative_Docs: ['Auch in dieser Woche bieten wir Ihnen wieder Fortbildungen für Lehre und Forschung Im Angebot sind die Videoplattform vBrick Werkzeuge zur Korpusanalyse Open Access in Minuten und das Thema digitale Prüfungen Schauen Sie doch mal rein', 'Auch in dieser Woche bieten wir Ihnen wieder Fortbildungen für Lehre und Forschung Im Angebot sind die Videoplattform vBrick Werkzeuge zur Korpusanalyse Open Access in Minuten und das Thema digitale Prüfungen Schauen Sie doch mal rein', 'Auch in dieser Woche bieten wir Ihnen wieder Fortbildungen für Lehre und Forschung Im Angebot sind die Videoplattform vBrick Werkzeuge zur Korpusanalyse Open Access in Minuten und das Thema digitale Prüfungen Schauen Sie doch mal rein']
#
# Thema 3:
# Representation: ['mecfs', 'versorgung', 'mecfsimbundestag', 'forschung', 'longcovid', 'mehr', 'gibt', 'menschen', 'jahrzehnten', 'helfen']
# Representative_Docs: ['MECFSimBundestag Heute nach Jahrzehnten ohne med Versorgung und Forschung Bagatellisierung und Psychomatisierung wird MECFS im Plenum des Deutschen Bundestages beraten Es muss was geschehen Ausreden gelten nicht mehr Ich bin seit Mai bettlägerig kein Hausarzt', 'MECFSimBundestag Heute nach Jahrzehnten ohne med Versorgung und Forschung Bagatellisierung und Psychomatisierung wird MECFS im Plenum des Deutschen Bundestages beraten Es muss was geschehen Ausreden gelten nicht mehr Ich bin seit Mai bettlägerig kein Hausarzt', 'MECFSimBundestag Heute nach Jahrzehnten ohne med Versorgung und Forschung Bagatellisierung und Psychomatisierung wird MECFS im Plenum des Deutschen Bundestages beraten Es muss was geschehen Ausreden gelten nicht mehr Ich bin seit Mai bettlägerig kein Hausarzt']
#
# Thema 4:
# Representation: ['berlin', 'freuen', 'bewerbungen', 'exzellente', 'heimatort', 'brain', 'wusstet', 'istberlin', 'wirberlin', 'klimaneutralen']
# Representative_Docs: ['Wusstet ihr dass Berlin DER Heimatort von Wissenschaft Technologie und Forschung istBerlin ist eine echte Brain City wo sich Forscherinnen mit spannenden Themen wie beispielsweise klimaneutralen Krankenhäusern beschäftigen Check it out WirBerlin', 'Wusstet ihr dass Berlin DER Heimatort von Wissenschaft Technologie und Forschung istBerlin ist eine echte Brain City wo sich Forscherinnen mit spannenden Themen wie beispielsweise klimaneutralen Krankenhäusern beschäftigen Check it out WirBerlin', 'Wusstet ihr dass Berlin DER Heimatort von Wissenschaft Technologie und Forschung istBerlin ist eine echte Brain City wo sich Forscherinnen mit spannenden Themen wie beispielsweise klimaneutralen Krankenhäusern beschäftigen Check it out WirBerlin']
#
# Thema 5:
# Representation: ['heißt', 'longcovid', 'covid', 'viren', 'prävention', 'endemisch', 'respiratorischen', 'endemie', 'erreger', 'therapeutika']
# Representative_Docs: ['Endemie heißt nicht dass ein Erreger harmlos ist Endemisch heißt auch nicht dass man keinen Infektionsschutz mehr braucht Prävention oder Therapeutika und Forschung Auch nicht dass man den bisherigen Umgang mit respiratorischen Viren nicht mal generell hinterfragen sollte', 'Endemie heißt nicht dass ein Erreger harmlos ist Endemisch heißt auch nicht dass man keinen Infektionsschutz mehr braucht Prävention oder Therapeutika und Forschung Auch nicht dass man den bisherigen Umgang mit respiratorischen Viren nicht mal generell hinterfragen sollte', 'Endemie heißt nicht dass ein Erreger harmlos ist Endemisch heißt auch nicht dass man keinen Infektionsschutz mehr braucht Prävention oder Therapeutika und Forschung Auch nicht dass man den bisherigen Umgang mit respiratorischen Viren nicht mal generell hinterfragen sollte']
#
# Thema 6:
# Representation: ['kernfusion', 'wasserstoff', 'alternative', 'energie', 'fusion', 'alten', 'akutheit', 'fusionshype', 'grünen', 'akw']
# Representative_Docs: ['Und was ist die Alternative in der Akutheit der Energiekrise Was ist mit alten PV Anlagen die nicht recycelt werden können und stattdessen nach Afrika zur Verschrottung geschickt werden Warum keine GenAKWForschung die Fossile ersetzen und Atommüll reduzieren können', 'Und was ist die Alternative in der Akutheit der Energiekrise Was ist mit alten PV Anlagen die nicht recycelt werden können und stattdessen nach Afrika zur Verschrottung geschickt werden Warum keine GenAKWForschung die Fossile ersetzen und Atommüll reduzieren können', 'Auch nochmal hier die Frage Für welche Alternative zur Braunkohle in Zeiten der Energieknappheit plädiert ihr AKW LNG EE sind weder so schnell in der Menge verfügbar noch zu ausgereift solange wir Umweltprobleme in die Welt verlagern Und was ist die Alternative in der Akutheit der Energiekrise Was ist mit alten PV Anlagen die nicht recycelt werden können und stattdessen nach Afrika zur Verschrottung geschickt werden Warum keine GenAKWForschung die Fossile ersetzen und Atommüll reduzieren können']
#
# Thema 7:
# Representation: ['geht', 'klima', 'engagiert', 'ehren', 'fleissig', 'klimaschützer', 'ansinnen', 'demonstrieren', 'demonstriert', 'demos']
# Representative_Docs: ['Manche Menschen verstehen einfach nicht was die Klimaforschung sagt in Jahren müssen die COEmissionen halbiert sein um das Pariser Abkommen einzuhalten Also nicht studieren und forschen sondern Ausstieg aus fossilen und EEAusbau sofort sind notwendig Liebe Klimaschützer Euer Ansinnen in allen Ehren Also geht nicht demonstrieren sondern fleissig an die Uni und danach engagiert in die Forschung Falls Ihr lieber demonstriert geht nach China Da werden Demos für das Klima sehr dringend gebraucht', 'Manche Menschen verstehen einfach nicht was die Klimaforschung sagt in Jahren müssen die COEmissionen halbiert sein um das Pariser Abkommen einzuhalten Also nicht studieren und forschen sondern Ausstieg aus fossilen und EEAusbau sofort sind notwendig Liebe Klimaschützer Euer Ansinnen in allen Ehren Also geht nicht demonstrieren sondern fleissig an die Uni und danach engagiert in die Forschung Falls Ihr lieber demonstriert geht nach China Da werden Demos für das Klima sehr dringend gebraucht', 'Manche Menschen verstehen einfach nicht was die Klimaforschung sagt in Jahren müssen die COEmissionen halbiert sein um das Pariser Abkommen einzuhalten Also nicht studieren und forschen sondern Ausstieg aus fossilen und EEAusbau sofort sind notwendig Liebe Klimaschützer Euer Ansinnen in allen Ehren Also geht nicht demonstrieren sondern fleissig an die Uni und danach engagiert in die Forschung Falls Ihr lieber demonstriert geht nach China Da werden Demos für das Klima sehr dringend gebraucht']
#
# Thema 8:
# Representation: ['frauen', 'genderstudies', 'mädchen', 'wissenschaftlerinnen', 'wissenschaft', 'weise', 'womeninscience', 'personen', 'tag', 'internationalen']
# Representative_Docs: ['Wenn du über Jahre ach was Jahrzehnte in nervtötendster Weise mit absurden Behauptungen über dein Forschungsfeld konfrontiert wirst Forschung lesen diese Personen nicht sie wissen ja immer schon Bescheid ne und NULL Verbesserung siehst Wie reagierst du GenderStudies', 'Wenn du über Jahre ach was Jahrzehnte in nervtötendster Weise mit absurden Behauptungen über dein Forschungsfeld konfrontiert wirst Forschung lesen diese Personen nicht sie wissen ja immer schon Bescheid ne und NULL Verbesserung siehst Wie reagierst du GenderStudies', 'Wenn du über Jahre ach was Jahrzehnte in nervtötendster Weise mit absurden Behauptungen über dein Forschungsfeld konfrontiert wirst Forschung lesen diese Personen nicht sie wissen ja immer schon Bescheid ne und NULL Verbesserung siehst Wie reagierst du GenderStudies']
#
# Thema 9:
# Representation: ['käthe', 'ukraine', 'film', 'leichterstaatspreis', 'jüdin', 'minister', 'februar', 'heute', 'veranstaltung', 'schafft']
# Representative_Docs: ['Es ist nur eine Nebenepisode aber symbolpolitisch gravierend das Frauenministerium in Österreich schafft den Käthe LeichterStaatspreis ab Käthe Leichter war Sozialdemokratin und Jüdin Sie wurde im KZ Ravensbrück ermordet Sie hat zuvor ArbeiterinnenForschung betrieben', 'Es ist nur eine Nebenepisode aber symbolpolitisch gravierend das Frauenministerium in Österreich schafft den Käthe LeichterStaatspreis ab Käthe Leichter war Sozialdemokratin und Jüdin Sie wurde im KZ Ravensbrück ermordet Sie hat zuvor ArbeiterinnenForschung betrieben', 'Es ist nur eine Nebenepisode aber symbolpolitisch gravierend das Frauenministerium in Österreich schafft den Käthe LeichterStaatspreis ab Käthe Leichter war Sozialdemokratin und Jüdin Sie wurde im KZ Ravensbrück ermordet Sie hat zuvor ArbeiterinnenForschung betrieben']
#
# Thema 10:
# Representation: ['lothar', 'wieler', 'dankewieler', 'rki', 'amt', 'verlässt', 'widmen', 'niederlegen', 'aufgaben', 'april']
# Representative_Docs: ['Professor Lothar H Wieler verlässt das RKI Er wird zum April sein Amt niederlegen um sich neuen Aufgaben in Forschung und Lehre zu widmen Alle Informationen in der gemeinsamen Pressemitteilung mit dem DankeWieler', 'Professor Lothar H Wieler verlässt das RKI Er wird zum April sein Amt niederlegen um sich neuen Aufgaben in Forschung und Lehre zu widmen Alle Informationen in der gemeinsamen Pressemitteilung mit dem DankeWieler', 'Professor Lothar H Wieler verlässt das RKI Er wird zum April sein Amt niederlegen um sich neuen Aufgaben in Forschung und Lehre zu widmen Alle Informationen in der gemeinsamen Pressemitteilung mit dem DankeWieler']

# %%
model.visualize_topics()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="34d17522-4572-40f7-8397-cc5370822c06" class="plotly-graph-div" style="height:650px; width:650px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("34d17522-4572-40f7-8397-cc5370822c06")) {                    Plotly.newPlot(                        "34d17522-4572-40f7-8397-cc5370822c06",                        [{"customdata":[[0,"forschung | ichbinhanna | wissenschaft | lehre | immer",736],[1,"forschung | digitale | the | lehre | thema",328],[2,"mecfs | versorgung | mecfsimbundestag | forschung | longcovid",294],[3,"berlin | freuen | bewerbungen | exzellente | heimatort",164],[4,"hei\u00dft | longcovid | covid | viren | pr\u00e4vention",141],[5,"kernfusion | wasserstoff | alternative | energie | fusion",120],[6,"geht | klima | engagiert | ehren | fleissig",113],[7,"frauen | genderstudies | m\u00e4dchen | wissenschaftlerinnen | wissenschaft",106],[8,"k\u00e4the | ukraine | film | leichterstaatspreis | j\u00fcdin",84],[9,"lothar | wieler | dankewieler | rki | amt",67],[10,"pflanzen | albrechtthaerweg | rundgang | gene | spuren",66],[11,"arch\u00e4ologie | germanen | kultur | meldungen | aktuell",53],[12,"pfizers | gofforschung | malone | \u00fcbersetzung | eingest\u00e4ndnis",37],[13,"mobilit\u00e4t | niedriger | verkehr | stra\u00dfen | sozio\u00f6konomischer",31],[14,"kindertagesbetreuung | gewalt | forschungsethik | straftaten | problemwarum",30],[15,"phdlife | phd | hast | christmas | kindergrundsicherung",30],[16,"psychotherapie | verfahren | allgemeinverst\u00e4ndlich | traumerleben | traumatisierten",29],[17,"stellenausschreibung | bewerbungsfrist | professur | medienbildung | besetzten",24],[18,"stream | anmeldeformular | tiktoktagung | dresden | meldet",22],[19,"jahr | weihnachten | w\u00fcnschen | schenke | geformte",20],[20,"mal | entscheidenden | helfe | gofforschung | best\u00e4tigt",20],[21,"tiere | tierversuche | wurden | gez\u00fcchtet | get\u00f6tet",19],[22,"staatssekret\u00e4rin | bundesministerium | bielefeld | neue | epple",15],[23,"ufoforschung | update | ifouniversit\u00e4t | flugobjekte | breakingnews",15],[24,"stressoren | st\u00e4rkste | resilienzcoachings | arbeitsverh\u00e4ltnisses | befristung",14],[25,"quem | est\u00e1 | ano | este | wer",14],[26,"verbot | gainoffunctionforschung | maskenpflicht | fordern | eigentlich",12],[27,"tagungshomepage | checkt | memefication | performance | merkt",12],[28,"fleisch | adipositas | fleischkonsum | ern\u00e4hrung | bereitschaft",12]],"hovertemplate":"\u003cb\u003eTopic %{customdata[0]}\u003c\u002fb\u003e\u003cbr\u003e%{customdata[1]}\u003cbr\u003eSize: %{customdata[2]}","legendgroup":"","marker":{"color":"#B0BEC5","size":[736,328,294,164,141,120,113,106,84,67,66,53,37,31,30,30,29,24,22,20,20,19,15,15,14,14,12,12,12],"sizemode":"area","sizeref":0.46,"symbol":"circle","line":{"color":"DarkSlateGrey","width":2}},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[10.88464069366455,12.015741348266602,10.021084785461426,-3.134639263153076,10.21602725982666,9.251365661621094,9.421717643737793,10.608075141906738,-4.464550971984863,12.17182731628418,10.304131507873535,-4.657865047454834,9.679534912109375,-3.5637316703796387,10.808789253234863,10.629430770874023,9.75931167602539,11.802281379699707,-2.9867520332336426,11.576943397521973,10.558793067932129,10.325578689575195,-3.353811025619507,9.449440956115723,9.90902328491211,-4.8861403465271,10.454011917114258,11.829686164855957,10.113723754882812],"xaxis":"x","y":[8.055912017822266,6.961796283721924,4.424863338470459,9.048945426940918,3.884058713912964,8.324509620666504,8.349455833435059,7.7743659019470215,7.869897365570068,7.320913314819336,8.076210021972656,7.700202465057373,3.579017400741577,8.609597206115723,8.410391807556152,8.098382949829102,4.7029 ...

# %%
model.visualize_barchart(top_n_topics = 10, n_words = 5)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="3dfc26db-dd21-46eb-aebf-e59bc6993d3f" class="plotly-graph-div" style="height:750px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3dfc26db-dd21-46eb-aebf-e59bc6993d3f")) {                    Plotly.newPlot(                        "3dfc26db-dd21-46eb-aebf-e59bc6993d3f",                        [{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.01386538002799386,0.01601573069229478,0.016987876608214558,0.019206095254865576,0.031455876583528435],"y":["immer  ","lehre  ","wissenschaft  ","ichbinhanna  ","forschung  "],"type":"bar","xaxis":"x","yaxis":"y"},{"marker":{"color":"#0072B2"},"orientation":"h","x":[0.01681235470376632,0.017721532240655317,0.018952070466489293,0.019311063436949404,0.02422876799520991],"y":["thema  ","lehre  ","the  ","digitale  ","forschung  "],"type":"bar","xaxis":"x2","yaxis":"y2"},{"marker":{"color":"#CC79A7"},"orientation":"h","x":[0.022511207465217835,0.0234489123266823,0.023806019264413513,0.03218080742822986,0.051183717474497493],"y":["longcovid  ","forschung  ","mecfsimbundestag  ","versorgung  ","mecfs  "],"type":"bar","xaxis":"x3","yaxis":"y3"},{"marker":{"color":"#E69F00"},"orientation":"h","x":[0.026917507319067637,0.02903010060340029,0.029209484253727293,0.03359811333625242,0.058556711814611355],"y":["heimatort  ","exzellente  ","bewerbungen  ","freuen  ","berlin  "],"type":"bar","xaxis":"x4","yaxis":"y4"},{"marker":{"color":"#56B4E9"},"orientation":"h","x":[0.04080019937314672,0.044707772432072426,0.048275007172305,0.05598907117971008,0.06451121768928286],"y":["pr\u00e4vention  ","viren  ","covid  ","longcovid  ","hei\u00dft  "],"type":"bar","xaxis":"x5","yaxis":"y5"},{"marker":{"color":"#009E73"},"orientation":"h","x":[0.026818163472855105,0.033622629872283906,0.03491839628244155,0.036082605094423154,0.05281628168803792],"y":["fusion  ","energie  ","alternative  ","wasserstoff  ","kernfusion  "],"type":"bar","xaxis":"x6","yaxis":"y6"},{"marker":{"color":"#F0E442"},"orientation":"h","x":[0.06052939017685705,0.06052939017685705,0.06186219058339956,0.06371669897881652,0.06937084391876322],"y":["fleissig  ","ehren  ","engagiert  ","klima  ","geht  "],"type":"bar","xaxis":"x7","yaxis":"y7"},{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.0310639022641129,0.032006835918976434,0.0384380128347264,0.04162002903473941,0.06465141066159483],"y":["wissenschaft  ","wissenschaftlerinnen  ","m\u00e4dchen  ","genderstudies  ","frauen  "],"type":"bar","xaxis":"x8","yaxis":"y8"},{"marker":{"color":"#0072B2"},"orientation":"h","x":[0.028331364844502435,0.028331364844502435,0.02876225081515838,0.03691356783783009,0.04474127904580193],"y":["j\u00fcdin  ","leichterstaatspreis  ","film  ","ukraine  ","k\u00e4the  "],"type":"bar","xaxis":"x9","yaxis":"y9"},{"marker":{"color":"#CC79A7"},"orientation":"h","x":[0.13016425711606133,0.134966859831147,0.14859170022102658,0.15583422981999262,0.15883629764508964],"y":["amt  ","rki  ","dankewieler  ","wieler  ","lothar  "],"type":"bar","xaxis":"x10","yaxis":"y10"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}], ...

# %%
model.visualize_heatmap()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="e1514ded-b80b-4b14-b8e3-acc2d1c381b5" class="plotly-graph-div" style="height:800px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e1514ded-b80b-4b14-b8e3-acc2d1c381b5")) {                    Plotly.newPlot(                        "e1514ded-b80b-4b14-b8e3-acc2d1c381b5",                        [{"coloraxis":"coloraxis","name":"0","x":["0_forschung_ichbinhanna_wis...","1_forschung_digitale_the","2_mecfs_versorgung_mecfsimb...","3_berlin_freuen_bewerbungen","4_hei\u00dft_longcovid_covid","5_kernfusion_wasserstoff_al...","6_geht_klima_engagiert","7_frauen_genderstudies_m\u00e4dc...","8_k\u00e4the_ukraine_film","9_lothar_wieler_dankewieler","10_pflanzen_albrechtthaerwe...","11_arch\u00e4ologie_germanen_kul...","12_pfizers_gofforschung_mal...","13_mobilit\u00e4t_niedriger_verk...","14_kindertagesbetreuung_gew...","15_phdlife_phd_hast","16_psychotherapie_verfahren...","17_stellenausschreibung_bew...","18_stream_anmeldeformular_t...","19_jahr_weihnachten_w\u00fcnschen","20_mal_entscheidenden_helfe","21_tiere_tierversuche_wurden","22_staatssekret\u00e4rin_bundesm...","23_ufoforschung_update_ifou...","24_stressoren_st\u00e4rkste_resi...","25_quem_est\u00e1_ano","26_verbot_gainoffunctionfor...","27_tagungshomepage_checkt_m...","28_fleisch_adipositas_fleis..."],"y":["0_forschung_ichbinhanna_wis...","1_forschung_digitale_the","2_mecfs_versorgung_mecfsimb...","3_berlin_freuen_bewerbungen","4_hei\u00dft_longcovid_covid","5_kernfusion_wasserstoff_al...","6_geht_klima_engagiert","7_frauen_genderstudies_m\u00e4dc...","8_k\u00e4the_ukraine_film","9_lothar_wieler_dankewieler","10_pflanzen_albrechtthaerwe...","11_arch\u00e4ologie_germanen_kul...","12_pfizers_gofforschung_mal...","13_mobilit\u00e4t_niedriger_verk...","14_kindertagesbetreuung_gew...","15_phdlife_phd_hast","16_psychotherapie_verfahren...","17_stellenausschreibung_bew...","18_stream_anmeldeformular_t...","19_jahr_weihnachten_w\u00fcnschen","20_mal_entscheidenden_helfe","21_tiere_tierversuche_wurden","22_staatssekret\u00e4rin_bundesm...","23_ufoforschung_update_ifou...","24_stressoren_st\u00e4rkste_resi...","25_quem_est\u00e1_ano","26_verbot_gainoffunctionfor...","27_tagungshomepage_checkt_m...","28_fleisch_adipositas_fleis..."],"z":[[0.9999999999999992,0.770082106935876,0.7456710095959509,0.6762481435108815,0.6391229639394791,0.6589825021719571,0.7467545127800629,0.6899348457944408,0.6226523680497454,0.42455768807720534,0.6724956111091528,0.43411417650558926,0.5462292224467181,0.4771727270740779,0.668803996404755,0.6634270280871476,0.6001768953609798,0.6171892813449941,0.24284045413683888,0.4495096201704263,0.33096737292196327,0.6109306102955704,0.36870036048318877,0.19738937777719523,0.5400099234632987,0.38627479198020365,0.5735848407334292,0.2956955517126614,0.47637601081423253],[0.770082106935876,1.0,0.7451081660068704,0.7347731490868239,0.4980193649021769,0.5127704211350259,0.6644628328844007,0.6480404969249904,0.7246229845075124,0.4840436777486139,0.6461444394073447,0.4870546101978948,0.5133458184039633,0.475422002068982,0.5764158397508845,0.6557241767584591,0.6465435558832444,0.7332998799527563,0.47039679052797934,0.597912926617082,0.42498527961197047,0.5227661258808998,0.4400619114364715,0.32484851705403384,0.4912423373526841,0.4292795270512968,0.45845461545501076,0.6052891493794296,0.4130222934478204],[0.7456710095959509,0.7451081660068704,0.9999999999999997,0.6422935430545721,0.7386058787382759,0.4985647799326207,0.6226665314796987,0.6097419365915011,0.5676776414504897,0.36834831140657043,0.5635489169166,0.3544519206483138,0.5170877416294775,0.40896590200157995,0.6045916931930261,0.5947478635821842,0.70098826878171,0.5162041784103356,0.3411043862432071,0.4953808223279642,0.33322174002108074,0.5792906365548336,0 ...

# %% [markdown]
# #### Themen nach Tweet-Kategorie

# %%
topics_per_class = model.topics_per_class(docs,
    classes=df.tweet_class)
# Out:
# 3it [00:00, 16.11it/s]

# %%
topics_per_class
# Out:
#     Topic                                                                                 Words  \
# 0      -1                                               forschung, the, heute, innovation, gute
# 1       0                            forschung, problem, wissenschaft, ichbinhanna, deutschland
# 2       1                              the, fdm, forschungsdatenmanagement, forschung, research
# 3       2                                  mecfs, versorgung, longcovid, mehr, mecfsimbundestag
# 4       3                                                 berlin, job, freuen, for, gratulieren
# 5       4                                                  longcovid, covid, heißt, viren, long
# 6       5                      kernfusion, alternative, akutheit, energiekrise, genakwforschung
# 7       6                                       klima, geht, engagiert, demonstrieren, fleissig
# 8       7                            frauen, genderstudies, mädchen, mint, wissenschaftlerinnen
# 9       8                                               film, käthe, etymologika, theologie, to
# 10      9                                                 dankewieler, lothar, wieler, rki, amt
# 11     10                                   führt, umweltbildung, anzuschauen, edna, baumkronen
# 12     11                     de, etienne, noémie, heritage, historischkulturwissenschaftlichen
# 13     12                             pfizers, gofforschung, malone, mrnapionier, eingeständnis
# 14     13                   mobilität, integration, migration, nachhaltige, integrationspolitik
# 15     14                         forschungsethik, straftaten, hammerstudie, spiegelonline, tun
# 16     15                                           phd, phdlife, christmas, phdmemes, academia
# 17     16         psychotherapie, verfahren, tiefenfundiert, traumatisierten, psychodynamischen
# 18     17           journalistische, relevant, stellenausschreibung, psychologie, medienbildung
# 19     18                                      stream, anmeldeformular, dresden, spread, meldet
# 20     19                                    golo, flaßhoff, florian, neuen, konfidenzintervall
# 21     21                                      tiere, seehundstation, martha, animals, nussbaum
# 22     22                  staatssekretärin, bundesministerium, neue, ernennung, ausgezeichnete
# 23     24                          stressoren, drei, wirtschaft, stärkste, arbeitsverhältnisses
# 24     25                                                            quem, está, ano, este, wer
# 25     26                           verbot, gainoffunctionforschung, fordern, eigentlich, frage
# 26     -1                                                    forschung, mehr, heute, gibt, gute
# 27      0                               forschung, ichbinhanna, wissenschaft, lehre, ermöglicht
# 28      1                                              forschung, digitale, the, lehre, chatgpt
# 29      2                             mecfs, versorgung, mecfsimbundestag, longcovid, forschung
# 30      3                                    berlin, freuen, exzellente, bewerbungen, heimatort
# 31      4                                           heißt, longcovid, viren, endemie, endemisch
# 32      5                                kernfusion, energie, fusionshype, wasserstoff, erzeugt
# 33      6                                               geht, engagiert, klima, ehren, fleissig
# 34      7                          frauen, genderstudies, mädchen, wissenschaft, womeninscience
# 35      8                                   käthe, ukraine, jüdin, leichterstaatspreis, schafft
# 36      9                                            lothar, wieler, dankewieler, rki, verlässt
# 37     10                                    pflanzen, rundgang, albrechtthaerweg, gene, spuren
# 38     11                                  archäologie, kultur, meldungen, aktuell, nachrichten
# 39     12                                  pfizers, gofforschung, malone, mrnapionier, holprige
# 40     13                             niedriger, verkehr, mobilität, straßen, sozioökonomischer
# 41     14         gewalt, forschungsethik, straftaten, familiengerichtlichen, justizministerium
# 42     15                        hast, programmieren, affin, kindergrundsicherung, sozialpolitk
# 43     16  psychotherapie, allgemeinverständlich, traumerleben, tiefenfundiert, traumatisierten
# 44     17            stellenausschreibung, bewerbungsfrist, professur, medienbildung, besetzten
# 45     18                                stream, anmeldeformular, tiktoktagung, dresden, meldet
# 46     19                                    jahr, weihnachten, datenzugang, wünschen, geformte
# 47     20                                       entscheidenden, gestern, mal, helfe, arbeitstag
# 48     21                                       tiere, tierversuche, wurden, gezüchtet, getötet
# 49     22                           staatssekretärin, bundesministerium, bielefeld, neue, epple
# 50     24            stressoren, arbeitsverhältnisses, resilienzcoachings, stärkste, befristung
# 51     25                                                            quem, está, ano, este, wer
# 52     26                   maskenpflicht, gainoffunctionforschung, verbot, fordern, dramatisch
# 53     27                             memefication, checkt, tagungshomepage, performance, merkt
# 54     28                                  fleisch, ernährung, fleischkonsum, bereitschaft, via
# 55     -1                                                      forschung, gibt, heute, mehr, ja
# 56      0                                              forschung, lehre, ja, immer, ichbinhanna
# 57      1                                             forschung, prof, digitale, lehre, vortrag
# 58      2                                              mecfs, versorgung, forschung, mehr, gibt
# 59      3                                 berlin, ausgezeichnet, freuen, forschung, psychologie
# 60      4                                                  covid, longcovid, heißt, long, virus
# 61      5                                            kernfusion, wasserstoff, gas, energie, akw
# 62      6                                   klimaforschung, nachhaltigkeit, klima, geht, danach
# 63      7                                         frauen, genderstudies, mädchen, gender, weise
# 64      8                                                  heute, rus, museum, kurzer, minister
# 65      9                                              poste, kaffee, katzenvideos, joinus, shk
# 66     10                            pflanzen, gene, rundgang, albrechtthaerweg, landwirtschaft
# 67     11              germanen, germanisch, raubeinige, germanischesprachen, differenzierteres
# 68     12                                           pfizers, gofforschung, malone, uno, sarscov
# 69     13                        tempo, mobilitätsregion, braunschweigwolfsburg, tempolimit, co
# 70     14                    kindertagesbetreuung, seitigen, erik, surveys, familienunternehmen
# 71     15                                                    phdlife, bereit, phd, studiums, my
# 72     16                 psychotherapie, trauma, erkrankungen, transgenerationales, epigenetik
# 73     17                                      bla, bewerbungsfrist, mwd, belästigung, mediatoo
# 74     19                                          jahr, wünschen, weihnachten, feiertage, neue
# 75     20                                   mal, gofforschung, entscheidenden, helfe, bestätigt
# 76     21                                         tierversuche, tiere, tierwohl, lassen, wurden
# 77     23                       ufoforschung, update, ifouniversität, breakingnews, flugobjekte
# 78     24            stressoren, arbeitsverhältnisses, stärkste, resilienzcoachings, befristung
# 79     28                       adipositas, fleisch, fleischkonsum, bereitschaft, erkenntnissen
#
#     Frequency        Class                                         Name
# 0         134  zitat_tweet                 -1_forschung_heute_gibt_mehr
# 1          73  zitat_tweet  0_forschung_ichbinhanna_wissenschaft_leh...
# 2          37  zitat_tweet               1_forschung_digitale_the_lehre
# 3          30  zitat_tweet  2_mecfs_versorgung_mecfsimbundestag_fors...
# 4          18  zitat_tweet       3_berlin_freuen_bewerbungen_exzellente
# 5          13  zitat_tweet                4_heißt_longcovid_covid_viren
# 6          30  zitat_tweet  5_kernfusion_wasserstoff_alternative_ene...
# 7          17  zitat_tweet                 6_geht_klima_engagiert_ehren
# 8          11  zitat_tweet  7_frauen_genderstudies_mädchen_wissensch...
# 9          14  zitat_tweet     8_käthe_ukraine_film_leichterstaatspreis
# 10         21  zitat_tweet              9_lothar_wieler_dankewieler_rki
# 11          4  zitat_tweet  10_pflanzen_albrechtthaerweg_rundgang_ge...
# 12          9  zitat_tweet     11_archäologie_germanen_kultur_meldungen
# 13          2  zitat_tweet  12_pfizers_gofforschung_malone_übersetzu...
# 14          2  zitat_tweet       13_mobilität_niedriger_verkehr_straßen
# 15          5  zitat_tweet  14_kindertagesbetreuung_gewalt_forschung...
# 16          7  zitat_tweet                15_phdlife_phd_hast_christmas
# 17          3  zitat_tweet  16_psychotherapie_verfahren_allgemeinver...
# 18          2  zitat_tweet  17_stellenausschreibung_bewerbungsfrist_...
# 19          3  zitat_tweet  18_stream_anmeldeformular_tiktoktagung_d...
# 20          2  zitat_tweet         19_jahr_weihnachten_wünschen_schenke
# 21          2  zitat_tweet       21_tiere_tierversuche_wurden_gezüchtet
# 22          4  zitat_tweet  22_staatssekretärin_bundesministerium_bi...
# 23          2  zitat_tweet  24_stressoren_stärkste_resilienzcoaching...
# 24          2  zitat_tweet                        25_quem_está_ano_este
# 25          1  zitat_tweet  26_verbot_gainoffunctionforschung_masken...
# 26        523      retweet                 -1_forschung_heute_gibt_mehr
# 27        293      retweet  0_forschung_ichbinhanna_wissenschaft_leh...
# 28        205      retweet               1_forschung_digitale_the_lehre
# 29        183      retweet  2_mecfs_versorgung_mecfsimbundestag_fors...
# 30        115      retweet       3_berlin_freuen_bewerbungen_exzellente
# 31         81      retweet                4_heißt_longcovid_covid_viren
# 32         53      retweet  5_kernfusion_wasserstoff_alternative_ene...
# 33         72      retweet                 6_geht_klima_engagiert_ehren
# 34         62      retweet  7_frauen_genderstudies_mädchen_wissensch...
# 35         50      retweet     8_käthe_ukraine_film_leichterstaatspreis
# 36         45      retweet              9_lothar_wieler_dankewieler_rki
# 37         43      retweet  10_pflanzen_albrechtthaerweg_rundgang_ge...
# 38         25      retweet     11_archäologie_germanen_kultur_meldungen
# 39         27      retweet  12_pfizers_gofforschung_malone_übersetzu...
# 40         20      retweet       13_mobilität_niedriger_verkehr_straßen
# 41         10      retweet  14_kindertagesbetreuung_gewalt_forschung...
# 42          8      retweet                15_phdlife_phd_hast_christmas
# 43         18      retweet  16_psychotherapie_verfahren_allgemeinver...
# 44         19      retweet  17_stellenausschreibung_bewerbungsfrist_...
# 45         19      retweet  18_stream_anmeldeformular_tiktoktagung_d...
# 46          7      retweet         19_jahr_weihnachten_wünschen_schenke
# 47          3      retweet     20_mal_entscheidenden_helfe_gofforschung
# 48          9      retweet       21_tiere_tierversuche_wurden_gezüchtet
# 49         11      retweet  22_staatssekretärin_bundesministerium_bi...
# 50         10      retweet  24_stressoren_stärkste_resilienzcoaching...
# 51         12      retweet                        25_quem_está_ano_este
# 52         11      retweet  26_verbot_gainoffunctionforschung_masken...
# 53         12      retweet  27_tagungshomepage_checkt_memefication_p...
# 54          9      retweet  28_fleisch_adipositas_fleischkonsum_ernä...
# 55        464        tweet                 -1_forschung_heute_gibt_mehr
# 56        370        tweet  0_forschung_ichbinhanna_wissenschaft_leh...
# 57         86        tweet               1_forschung_digitale_the_lehre
# 58         81        tweet  2_mecfs_versorgung_mecfsimbundestag_fors...
# 59         31        tweet       3_berlin_freuen_bewerbungen_exzellente
# 60         47        tweet                4_heißt_longcovid_covid_viren
# 61         37        tweet  5_kernfusion_wasserstoff_alternative_ene...
# 62         24        tweet                 6_geht_klima_engagiert_ehren
# 63         33        tweet  7_frauen_genderstudies_mädchen_wissensch...
# 64         20        tweet     8_käthe_ukraine_film_leichterstaatspreis
# 65          1        tweet              9_lothar_wieler_dankewieler_rki
# 66         19        tweet  10_pflanzen_albrechtthaerweg_rundgang_ge...
# 67         19        tweet     11_archäologie_germanen_kultur_meldungen
# 68          8        tweet  12_pfizers_gofforschung_malone_übersetzu...
# 69          9        tweet       13_mobilität_niedriger_verkehr_straßen
# 70         15        tweet  14_kindertagesbetreuung_gewalt_forschung...
# 71         15        tweet                15_phdlife_phd_hast_christmas
# 72          8        tweet  16_psychotherapie_verfahren_allgemeinver...
# 73          3        tweet  17_stellenausschreibung_bewerbungsfrist_...
# 74         11        tweet         19_jahr_weihnachten_wünschen_schenke
# 75         17        tweet     20_mal_entscheidenden_helfe_gofforschung
# 76          8        tweet       21_tiere_tierversuche_wurden_gezüchtet
# 77         15        tweet  23_ufoforschung_update_ifouniversität_fl...
# 78          2        tweet  24_stressoren_stärkste_resilienzcoaching...
# 79          3        tweet  28_fleisch_adipositas_fleischkonsum_ernä...

# %%
model.visualize_topics_per_class(topics_per_class,
    top_n_topics=10, normalize_frequency = True)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="9a1da6c1-46e7-4098-ba95-143d365116fe" class="plotly-graph-div" style="height:900px; width:1250px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9a1da6c1-46e7-4098-ba95-143d365116fe")) {                    Plotly.newPlot(                        "9a1da6c1-46e7-4098-ba95-143d365116fe",                        [{"hoverinfo":"text","hovertext":["\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: forschung, problem, wissenschaft, ichbinhanna, deutschland","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: forschung, ichbinhanna, wissenschaft, lehre, erm\u00f6glicht","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: forschung, lehre, ja, immer, ichbinhanna"],"marker":{"color":"#E69F00"},"name":"0_forschung_ichbinhanna_wissenschaft_leh...","orientation":"h","visible":true,"x":[0.1528555324212146,0.6135160410878888,0.7747472191212247],"y":["zitat_tweet","retweet","tweet"],"type":"bar"},{"hoverinfo":"text","hovertext":["\u003cb\u003eTopic 1\u003c\u002fb\u003e\u003cbr\u003eWords: the, fdm, forschungsdatenmanagement, forschung, research","\u003cb\u003eTopic 1\u003c\u002fb\u003e\u003cbr\u003eWords: forschung, digitale, the, lehre, chatgpt","\u003cb\u003eTopic 1\u003c\u002fb\u003e\u003cbr\u003eWords: forschung, prof, digitale, lehre, vortrag"],"marker":{"color":"#56B4E9"},"name":"1_forschung_digitale_the_lehre","orientation":"h","visible":"legendonly","x":[0.16417711420207748,0.9096299570655645,0.3816008600372612],"y":["zitat_tweet","retweet","tweet"],"type":"bar"},{"hoverinfo":"text","hovertext":["\u003cb\u003eTopic 2\u003c\u002fb\u003e\u003cbr\u003eWords: mecfs, versorgung, longcovid, mehr, mecfsimbundestag","\u003cb\u003eTopic 2\u003c\u002fb\u003e\u003cbr\u003eWords: mecfs, versorgung, mecfsimbundestag, longcovid, forschung","\u003cb\u003eTopic 2\u003c\u002fb\u003e\u003cbr\u003eWords: mecfs, versorgung, forschung, mehr, gibt"],"marker":{"color":"#009E73"},"name":"2_mecfs_versorgung_mecfsimbundestag_fors...","orientation":"h","visible":"legendonly","x":[0.14824986333222023,0.9043241663265434,0.4002746309969946],"y":["zitat_tweet","retweet","tweet"],"type":"bar"},{"hoverinfo":"text","hovertext":["\u003cb\u003eTopic 3\u003c\u002fb\u003e\u003cbr\u003eWords: berlin, job, freuen, for, gratulieren","\u003cb\u003eTopic 3\u003c\u002fb\u003e\u003cbr\u003eWords: berlin, freuen, exzellente, bewerbungen, heimatort","\u003cb\u003eTopic 3\u003c\u002fb\u003e\u003cbr\u003eWords: berlin, ausgezeichnet, freuen, forschung, psychologie"],"marker":{"color":"#F0E442"},"name":"3_berlin_freuen_bewerbungen_exzellente","orientation":"h","visible":"legendonly","x":[0.1494303449126146,0.9546938702750377,0.25735226068283623],"y":["zitat_tweet","retweet","tweet"],"type":"bar"},{"hoverinfo":"text","hovertext":["\u003cb\u003eTopic 4\u003c\u002fb\u003e\u003cbr\u003eWords: longcovid, covid, hei\u00dft, viren, long","\u003cb\u003eTopic 4\u003c\u002fb\u003e\u003cbr\u003eWords: hei\u00dft, longcovid, viren, endemie, endemisch","\u003cb\u003eTopic 4\u003c\u002fb\u003e\u003cbr\u003eWords: covid, longcovid, hei\u00dft, long, virus"],"marker":{"color":"#D55E00"},"name":"4_hei\u00dft_longcovid_covid_viren","orientation":"h","visible":"legendonly","x":[0.13749879231435788,0.8567232444202298,0.4971110183672939],"y":["zitat_tweet","retweet","tweet"],"type":"bar"},{"hoverinfo":"text","hovertext":["\u003cb\u003eTopic 5\u003c\u002fb\u003e\u003cbr\u003eWords: kernfusion, alternative, akutheit, energiekrise, genakwforschung","\u003cb\u003eTopic 5\u003c\u002fb\u003e\u003cbr\u003eWords: kernfusion, energie, fusionshype, wasserstoff, erzeugt","\u003cb\u003eTopic 5\u003c\u002fb\u003e\u003cbr\u003eWords: kernfusion, wasserstoff, gas, energie, akw"],"marker":{"color":"#0072B2"},"name":"5_kernfusion_wasserstoff_a ...

# %%
#fig = model.visualize_topics_per_class(topics_per_class)
#fig.write_html("path/to/file.html")
