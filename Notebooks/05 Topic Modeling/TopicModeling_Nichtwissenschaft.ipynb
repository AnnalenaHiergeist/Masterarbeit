# %% [markdown]
# ## Topic Modeling - Nichtwissenschaft-Datensatz

# %%
# !pip install bertopic

# %%
from bertopic import BERTopic

import pandas as pd
import re

import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')

from sklearn.feature_extraction.text import CountVectorizer
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %% [markdown]
# ### Daten einlesen & Preprocessing

# %%
df = pd.read_excel('tweets_nichtwissenschaft.xlsx')

# %%
df['tweet_text'] = df['tweet_text'].astype(str)
df['retweet_text_retweeted_tweet'] = df['retweet_text_retweeted_tweet'].astype(str)
df['zitat_text'] = df['zitat_text'].astype(str)

# %%
def classify_tweet(row):
    if row['tweet_text'] != '-998' and row['retweet_text_retweeted_tweet'] == '-998' and row['zitat_text'] == '-998':
        return 'tweet'
    elif row['retweet_text_retweeted_tweet'] != '-998':
        return 'retweet'
    elif row['tweet_text'] != '-998' and row['zitat_text'] != '-998':
        return 'zitat_tweet'
    return 'unclassified'

# %%
df['tweet_class'] = df.apply(classify_tweet, axis=1)

# %%
def gather_texts(row):
    texts = []
    for column in ['tweet_text', 'retweet_text_retweeted_tweet', 'zitat_text']:
      if pd.notna(row[column]) and str(row[column]) != '-998':
            texts.append(row[column])
    return ' '.join(texts)

# %%
df['all_tweets'] = df.apply(gather_texts, axis=1)

# %%
def preprocess_tweet(text):
    text = re.sub(r'@\w+', '', text)  # Entfernt Benutzernamen
    text = re.sub(r'http\S+', '', text)  # Entfernt URLs
    text = re.sub(r'www.\S+', '', text)  # Entfernt URLs
    text = re.sub(r'[0-9]+', '', text)  # Entfernt Zahlen
    text = re.sub(r'[^\w\s]', '', text)  # Entfernt Sonderzeichen
    text = re.sub(r'_', '', text)  # Entfernt Unterstriche
    text = re.sub(r'\s+', ' ', text).strip()  # Ersetzt mehrere Leerzeichen durch ein einzelnes und entfernt sie am Anfang/Ende
    text = re.sub(r'-998', '', text)  # entfernt fehlende Werte
    text = re.sub(r'nan', '', text)  # entfernt fehlende Werte

    return text

# %%
df['all_tweets'] = df['all_tweets'].apply(preprocess_tweet)

# %% [markdown]
# ### Topic Modeling mit BERTopic

# %%
docs = list(df.all_tweets.values)

german_stopwords = set(stopwords.words('german'))
stopwords = list(german_stopwords)
vectorizer_model = CountVectorizer(stop_words=stopwords)

# %% [markdown]
# #### Erstes Modell ohne Beschränkung der Themenanzahl

# %%
# BERTopic-Modell erstellen
model = BERTopic(language="German", calculate_probabilities=True, verbose=True, vectorizer_model=vectorizer_model)

# Model anwenden und Topics extrahieren
topics, probs = model.fit_transform(docs)

# %%
# Ergebnisse
print(f"Anzahl der Topics: {model.get_topic_info().shape[0] - 1}")  # Minus 1 wegen des Outliers-Topics (-1)
topic_info = model.get_topic_info()
topic_info.head(20)
# Out:
# Anzahl der Topics: 533
#     Topic  Count                                               Name  \
# 0      -1   5265                  -1_ja_gibt_forschung_wissenschaft
# 1       0    512        0_malone_löschungen_derailing_sonntagskrimi
# 2       1    269               1_halbiert_pariser_eeausbau_abkommen
# 3       2    251                     2_laborthese_bat_clique_farrar
# 4       3    219  3_enthüllungen_bertelsmannzensoren_bestätigte_...
# 5       4    175  4_impfung_impfschäden_impfstoff_impfnebenwirku...
# 6       5    171           5_heißt_endemie_respiratorischen_erreger
# 7       6    157               6_ruhiger_therapien_framen_gegenrede
# 8       7    150              7_directed_reagiert_begrenzten_fällen
# 9       8    150  8_gegenwärtige_ergebnissen_gründergeneration_m...
# 10      9    148  9_niederlegen_gemeinsamen_verlässt_pressemitte...
# 11     10    140  10_bürokratie_deutschland_zeitinterviews_nszwa...
# 12     11    128                11_kapitalismus_geld_kosten_bezahlt
# 13     12    120  12_tierversuche_tiere_tierversuchsfreie_gezüchtet
# 14     13    109  13_vorhandenes_forschergruppen_körpers_covidfo...
# 15     14    108           14_laser_brauchten_aufgesessen_tatsachen
# 16     15    102  15_krebsforschung_weltkrebstag_krebs_tumorerkr...
# 17     16    101    16_untersuchung_beginnen_entscheidungen_startet
# 18     17    100            17_ansinnen_ehren_demonstriert_fleissig
# 19     18     96          18_politiksprüche_zib_verzweifeln_verbote
#
#                                        Representation  \
# 0   [ja, gibt, forschung, wissenschaft, schon, wis...
# 1   [malone, löschungen, derailing, sonntagskrimi,...
# 2   [halbiert, pariser, eeausbau, abkommen, coemis...
# 3   [laborthese, bat, clique, farrar, unterdrücken...
# 4   [enthüllungen, bertelsmannzensoren, bestätigte...
# 5   [impfung, impfschäden, impfstoff, impfnebenwir...
# 6   [heißt, endemie, respiratorischen, erreger, en...
# 7   [ruhiger, therapien, framen, gegenrede, umgede...
# 8   [directed, reagiert, begrenzten, fällen, anzah...
# 9   [gegenwärtige, ergebnissen, gründergeneration,...
# 10  [niederlegen, gemeinsamen, verlässt, pressemit...
# 11  [bürokratie, deutschland, zeitinterviews, nszw...
# 12  [kapitalismus, geld, kosten, bezahlt, steuern,...
# 13  [tierversuche, tiere, tierversuchsfreie, gezüc...
# 14  [vorhandenes, forschergruppen, körpers, covidf...
# 15  [laser, brauchten, aufgesessen, tatsachen, ato...
# 16  [krebsforschung, weltkrebstag, krebs, tumorerk...
# 17  [untersuchung, beginnen, entscheidungen, start...
# 18  [ansinnen, ehren, demonstriert, fleissig, demo...
# 19  [politiksprüche, zib, verzweifeln, verbote, to...
#
#                                   Representative_Docs
# 0   [So Leute nicht vergessen HEUTE von Uhr MEAwar...
# 1   [Sonntagskrimi Legen Sie ihn weg das hier ist ...
# 2   [Manche Menschen verstehen einfach nicht was d...
# 3   [Die UNO bat zwei Professoren die Herkunft von...
# 4   [Pfizer bestätigte inzwischen die Enthüllungen...
# 5   [hier nur Auszüge Bevor aber wild spekuliert w...
# 6   [Endemie heißt nicht dass ein Erreger harmlos ...
# 7   [Man kann Gegenrede wenn das Krankheitserleben...
# 8   [Pfizer reagiert auf Projekt Veritas Pfizer ha...
# 9   [Sprecherin F Mayer erzählt dass ihr Verein se...
# 10  [Professor Lothar H Wieler verlässt das RKI Er...
# 11  [Deutschland bleibt Deutschland Einleitung des...
# 12  [Etat für Forschung und Bildung der noch viert...
# 13  [Wir haben heute ein neues Factsheet über Tier...
# 14  [Die CovidForschung macht gerade riesige Forts...
# 15  [Wer dem FusionsHype dieser Woche aufgesessen ...
# 16  [Herzlichen Glückwunsch und Das CCCE wird Teil...
# 17  [Senator Paul Fauci wird in die Geschichte ein...
# 18  [Liebe Klimaschützer Euer Ansinnen in allen Eh...
# 19  [Immer wieder dieselben Politiksprüche beim Kl...

# %%
model.visualize_topics()
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# #### Reduzierung der Themenanzahl

# %%
model.reduce_topics(docs, nr_topics=30)
# Out:
# 2024-04-29 12:55:37,970 - BERTopic - Topic reduction - Reducing number of topics
# 2024-04-29 12:55:40,526 - BERTopic - Topic reduction - Reduced number of topics from 534 to 30

# %%
# Ergebnisse
print(f"Anzahl der Topics: {model.get_topic_info().shape[0] - 1}")  # Minus 1 wegen des Outliers-Topics (-1)
topic_info = model.get_topic_info()
topic_info
# Out:
# Anzahl der Topics: 29
#     Topic  Count                                               Name  \
# 0      -1   5265                          -1_forschung_gibt_mehr_ja
# 1       0   6365                       0_forschung_geht_china_klima
# 2       1   5226       1_mecfs_longcovid_forschung_mecfsimbundestag
# 3       2   1232               2_pfizer_enthüllungen_pfizers_malone
# 4       3    872                 3_wieler_lothar_dankewieler_widmen
# 5       4    574                 4_berlin_protest_nichtgenesen_está
# 6       5    358   5_cannabis_zahl_gesamtsterblichkeit_verhinderten
# 7       6    312  6_frauen_selbstbestimmungsgesetz_gender_transf...
# 8       7    214           7_wer_demokratie_lobbyismus_eskalationen
# 9       8    209  8_ufoforschung_atlantikzirkulation_kipppunkt_s...
# 10      9    186     9_bildung_ministerin_bundesministerin_schützen
# 11     10    185       10_herr_käthe_steinmeier_leichterstaatspreis
# 12     11    146  11_weihnachten_longcovid_konfidenzintervall_ge...
# 13     12    135       12_allgemeinen_württemberg_kürzungen_gekürzt
# 14     13    117                 13_vielleicht_schon_addendum_mafia
# 15     14     96  14_verbot_gainoffunctionforschung_maskenpflich...
# 16     15     77               15_varianten_jahre_netto_pflegestufe
# 17     16     68  16_gefälscht_betrügerisch_genehmigungen_behörd...
# 18     17     64                         17_startup_ittrends_dsm_ar
# 19     18     48           18_alzheimer_demenz_vormittag_berichtete
# 20     19     37  19_ausschließlicher_pandemieplanspiel_afrikan_...
# 21     20     35                20_pokemongo_pokémon_go_befristeten
# 22     21     30     21_lrrc_protein_repeatcontaining_weiterzugeben
# 23     22     24             22_gebrauchtes_just_großzügig_soziales
# 24     23     18  23_scheidung_deepstate_schäfer_familienministe...
# 25     24     18  24_usölriese_verdeutlichung_ölkonzernen_explod...
# 26     25     15        25_türkiye_türkische_lokomotivmotor_tübitak
# 27     26     14              26_sportler_register_berührung_wenden
# 28     27     13          27_schlaf_schlafen_forschungsrechner_hero
# 29     28     12  28_aktenordner_dicken_mastzellaktivierungserkr...
#
#                                        Representation  \
# 0   [forschung, gibt, mehr, ja, wissenschaft, scho...
# 1   [forschung, geht, china, klima, müssen, mehr, ...
# 2   [mecfs, longcovid, forschung, mecfsimbundestag...
# 3   [pfizer, enthüllungen, pfizers, malone, löschu...
# 4   [wieler, lothar, dankewieler, widmen, amt, auf...
# 5   [berlin, protest, nichtgenesen, está, quem, sy...
# 6   [cannabis, zahl, gesamtsterblichkeit, verhinde...
# 7   [frauen, selbstbestimmungsgesetz, gender, tran...
# 8   [wer, demokratie, lobbyismus, eskalationen, re...
# 9   [ufoforschung, atlantikzirkulation, kipppunkt,...
# 10  [bildung, ministerin, bundesministerin, schütz...
# 11  [herr, käthe, steinmeier, leichterstaatspreis,...
# 12  [weihnachten, longcovid, konfidenzintervall, g...
# 13  [allgemeinen, württemberg, kürzungen, gekürzt,...
# 14  [vielleicht, schon, addendum, mafia, klausmich...
# 15  [verbot, gainoffunctionforschung, maskenpflich...
# 16  [varianten, jahre, netto, pflegestufe, kauft, ...
# 17  [gefälscht, betrügerisch, genehmigungen, behör...
# 18  [startup, ittrends, dsm, ar, vr, stuttgart, tr...
# 19  [alzheimer, demenz, vormittag, berichtete, dem...
# 20  [ausschließlicher, pandemieplanspiel, afrikan,...
# 21  [pokemongo, pokémon, go, befristeten, befriste...
# 22  [lrrc, protein, repeatcontaining, weiterzugebe...
# 23  [gebrauchtes, just, großzügig, soziales, steue...
# 24  [scheidung, deepstate, schäfer, familienminist...
# 25  [usölriese, verdeutlichung, ölkonzernen, explo...
# 26  [türkiye, türkische, lokomotivmotor, tübitak, ...
# 27  [sportler, register, berührung, wenden, todesf...
# 28  [schlaf, schlafen, forschungsrechner, hero, dr...
# 29  [aktenordner, dicken, mastzellaktivierungserkr...
#
#                                   Representative_Docs
# 0   [Vor allen Dingen sagt die Forschung schon sei...
# 1   [Manche Menschen verstehen einfach nicht was d...
# 2   [Ganz wichtig Am Donnerstag Januar demonstrier...
# 3   [Sonntagskrimi Legen Sie ihn weg das hier ist ...
# 4   [Professor Lothar H Wieler verlässt das RKI Er...
# 5   [Berlin Heute MECFSimBundestag Stiller Protest...
# 6   [Früher fragte die Forschung ob ein Krebsmitte...
# 7   [CN Transfeindlichkeit Wenn ein Institut für G...
# 8   [Den Kern des konservativen Denkens ist eine A...
# 9   [Der Kipppunkt der Atlantikzirkulation regt se...
# 10  [K Hallo Fr StarkWatzinger haben Sie das so ge...
# 11  [Ich frage mich warum der Zentralrat es nicht ...
# 12  [Weihnachten mit milden LongCovid MECFS konnte...
# 13  [Forschung und Lehre Budget wird in Mainz gekü...
# 14  [Googel in Rostock steht einer der größten Wet...
# 15  [Warum fordern eigentlich kein Verbot von Gain...
# 16  [Liebe zukünftige MECFSBetroffene was Karl nic...
# 17  [Die klinischen Versuche waren gefälscht Es la...
# 18  [Top Posts Most Innovative Companies ITTrends ...
# 19  [Heute Vormittag hatte ich einen Termin in ein...
# 20  [Am Oktober fand mit Beteiligung der ein weite...
# 21  [Wir haben eine Übersicht der Befristeten Fors...
# 22  [Dieses Protein das leucinerich repeatcontaini...
# 23  [Wer verteilt großzügig dringend zu Hause gebr...
# 24  [Kampf ums Kindeswohl Eine Studie soll klären ...
# 25  [Gewinne von Ölkonzernen explodiert Allein USÖ...
# 26  [Tübitak produziert Lokomotivmotor mit Biokraf...
# 27  [Heute will ich mich mit diesem Video an alle ...
# 28  [Im Schlaf Gutes tun Das geht Mit der Dreamlab...
# 29  [MCAS Was versteht man unter einer Mastzellakt...

# %%
for i in range(1, 11):
    representation = topic_info.loc[i, 'Representation']
    representative_docs = topic_info.loc[i, 'Representative_Docs']
    print(f"Thema {i}:")
    print(f"Representation: {representation}")
    print(f"Representative_Docs: {representative_docs}")
    print()
# Out:
# Thema 1:
# Representation: ['forschung', 'geht', 'china', 'klima', 'müssen', 'mehr', 'gebraucht', 'klimaschützer', 'lieber', 'demonstriert']
# Representative_Docs: ['Manche Menschen verstehen einfach nicht was die Klimaforschung sagt in Jahren müssen die COEmissionen halbiert sein um das Pariser Abkommen einzuhalten Also nicht studieren und forschen sondern Ausstieg aus fossilen und EEAusbau sofort sind notwendig Liebe Klimaschützer Euer Ansinnen in allen Ehren Also geht nicht demonstrieren sondern fleissig an die Uni und danach engagiert in die Forschung Falls Ihr lieber demonstriert geht nach China Da werden Demos für das Klima sehr dringend gebraucht', 'Manche Menschen verstehen einfach nicht was die Klimaforschung sagt in Jahren müssen die COEmissionen halbiert sein um das Pariser Abkommen einzuhalten Also nicht studieren und forschen sondern Ausstieg aus fossilen und EEAusbau sofort sind notwendig Liebe Klimaschützer Euer Ansinnen in allen Ehren Also geht nicht demonstrieren sondern fleissig an die Uni und danach engagiert in die Forschung Falls Ihr lieber demonstriert geht nach China Da werden Demos für das Klima sehr dringend gebraucht', 'Manche Menschen verstehen einfach nicht was die Klimaforschung sagt in Jahren müssen die COEmissionen halbiert sein um das Pariser Abkommen einzuhalten Also nicht studieren und forschen sondern Ausstieg aus fossilen und EEAusbau sofort sind notwendig Liebe Klimaschützer Euer Ansinnen in allen Ehren Also geht nicht demonstrieren sondern fleissig an die Uni und danach engagiert in die Forschung Falls Ihr lieber demonstriert geht nach China Da werden Demos für das Klima sehr dringend gebraucht']
#
# Thema 2:
# Representation: ['mecfs', 'longcovid', 'forschung', 'mecfsimbundestag', 'versorgung', 'mehr', 'covid', 'brauchen', 'seit', 'betroffene']
# Representative_Docs: ['Ganz wichtig Am Donnerstag Januar demonstrieren Betroffene der Krankheiten mecfs LongCovid postvac ab Uhr vor dem Bundestag Ein Meer aus Betten symbolisiert die Flut der Kranken Wir brauchen Forschung Anerkennung und Versorgung Gesundheit ist ein Menschenrecht', 'Ganz wichtig Am Donnerstag Januar demonstrieren Betroffene der Krankheiten mecfs LongCovid postvac ab Uhr vor dem Bundestag Ein Meer aus Betten symbolisiert die Flut der Kranken Wir brauchen Forschung Anerkennung und Versorgung Gesundheit ist ein Menschenrecht', 'MECFS ist seit über Jahren von der WHO als neurologische Erkrankung klassifiziert Dennoch wurden und werden MECFS Betroffene und deren Angehörige alleine gelassen MECFSimBundestag Heute nach Jahrzehnten ohne med Versorgung und Forschung Bagatellisierung und Psychomatisierung wird MECFS im Plenum des Deutschen Bundestages beraten Es muss was geschehen Ausreden gelten nicht mehr Ich bin seit Mai bettlägerig kein Hausarzt']
#
# Thema 3:
# Representation: ['pfizer', 'enthüllungen', 'pfizers', 'malone', 'löschungen', 'holprige', 'sonntagskrimi', 'derailing', 'mrnapionier', 'resoz']
# Representative_Docs: ['Sonntagskrimi Legen Sie ihn weg das hier ist spannender mRNAPionier Dr Robert Malone zeigt warum Pfizers Eingeständnis der GoFForschung in den Medien wenig Resoz fand Löschungen Bots Derailing das volle Programm Holprige Übersetzung hier', 'Sonntagskrimi Legen Sie ihn weg das hier ist spannender mRNAPionier Dr Robert Malone zeigt warum Pfizers Eingeständnis der GoFForschung in den Medien wenig Resoz fand Löschungen Bots Derailing das volle Programm Holprige Übersetzung hier', 'Sonntagskrimi Legen Sie ihn weg das hier ist spannender mRNAPionier Dr Robert Malone zeigt warum Pfizers Eingeständnis der GoFForschung in den Medien wenig Resoz fand Löschungen Bots Derailing das volle Programm Holprige Übersetzung hier']
#
# Thema 4:
# Representation: ['wieler', 'lothar', 'dankewieler', 'widmen', 'amt', 'aufgaben', 'verlässt', 'niederlegen', 'april', 'rki']
# Representative_Docs: ['Professor Lothar H Wieler verlässt das RKI Er wird zum April sein Amt niederlegen um sich neuen Aufgaben in Forschung und Lehre zu widmen Alle Informationen in der gemeinsamen Pressemitteilung mit dem DankeWieler', 'Professor Lothar H Wieler verlässt das RKI Er wird zum April sein Amt niederlegen um sich neuen Aufgaben in Forschung und Lehre zu widmen Alle Informationen in der gemeinsamen Pressemitteilung mit dem DankeWieler', 'Professor Lothar H Wieler verlässt das RKI Er wird zum April sein Amt niederlegen um sich neuen Aufgaben in Forschung und Lehre zu widmen Alle Informationen in der gemeinsamen Pressemitteilung mit dem DankeWieler']
#
# Thema 5:
# Representation: ['berlin', 'protest', 'nichtgenesen', 'está', 'quem', 'symbolisch', 'stiller', 'hunderttausende', 'wagner', 'maria']
# Representative_Docs: ['Berlin Heute MECFSimBundestag Stiller Protest von NichtGenesen Feldbetten symbolisch für Hunderttausende Betroffene Wir fordern Forschung Versorgung und Aufklärung Foto Maria Wagner', 'Berlin Heute MECFSimBundestag Stiller Protest von NichtGenesen Feldbetten symbolisch für Hunderttausende Betroffene Wir fordern Forschung Versorgung und Aufklärung Foto Maria Wagner', 'Berlin Heute MECFSimBundestag Stiller Protest von NichtGenesen Feldbetten symbolisch für Hunderttausende Betroffene Wir fordern Forschung Versorgung und Aufklärung Foto Maria Wagner']
#
# Thema 6:
# Representation: ['cannabis', 'zahl', 'gesamtsterblichkeit', 'verhinderten', 'töteten', 'krebstoten', 'krebstote', 'erkannte', 'krebsmittel', 'senkt']
# Representative_Docs: ['Früher fragte die Forschung ob ein Krebsmittel die Zahl der Krebstoten senkt Dann erkannte man den Fehler Starke Mittel töteten durch Nebenwirkungen mehr als sie Krebstote verhinderten Relevant ist nur die Wirkung auf die Gesamtsterblichkeit zu der es keine Daten gibt', 'Früher fragte die Forschung ob ein Krebsmittel die Zahl der Krebstoten senkt Dann erkannte man den Fehler Starke Mittel töteten durch Nebenwirkungen mehr als sie Krebstote verhinderten Relevant ist nur die Wirkung auf die Gesamtsterblichkeit zu der es keine Daten gibt', 'Früher fragte die Forschung ob ein Krebsmittel die Zahl der Krebstoten senkt Dann erkannte man den Fehler Starke Mittel töteten durch Nebenwirkungen mehr als sie Krebstote verhinderten Relevant ist nur die Wirkung auf die Gesamtsterblichkeit zu der es keine Daten gibt']
#
# Thema 7:
# Representation: ['frauen', 'selbstbestimmungsgesetz', 'gender', 'transfeindlichkeit', 'cn', 'weckruf', 'criticals', 'genozid', 'terfs', 'plattform']
# Representative_Docs: ['CN Transfeindlichkeit Wenn ein Institut für Genozid Forschung vor Gender Criticals TERFs warnt dann sollte das gerade HIER Weckruf genug sein Medien Hört auf denen Plattform zu geben und Selbstbestimmungsgesetz endlich umsetzen', 'CN Transfeindlichkeit Wenn ein Institut für Genozid Forschung vor Gender Criticals TERFs warnt dann sollte das gerade HIER Weckruf genug sein Medien Hört auf denen Plattform zu geben und Selbstbestimmungsgesetz endlich umsetzen', 'CN Transfeindlichkeit Wenn ein Institut für Genozid Forschung vor Gender Criticals TERFs warnt dann sollte das gerade HIER Weckruf genug sein Medien Hört auf denen Plattform zu geben und Selbstbestimmungsgesetz endlich umsetzen']
#
# Thema 8:
# Representation: ['wer', 'demokratie', 'lobbyismus', 'eskalationen', 'realitätsfeudalismus', 'verursacht', 'privilegierten', 'überstimmen', 'denkens', 'bezüglich']
# Representative_Docs: ['Den Kern des konservativen Denkens ist eine Art Realitätsfeudalismus Die Privilegierten entscheiden wer ein guter Ausländer ist und wer ein schlechter sie überstimmen auch Wissenschaft und Forschung Klimakatastrophe Pandemie Wer die Macht hat dem gehört die Wirklichkeit', 'Den Kern des konservativen Denkens ist eine Art Realitätsfeudalismus Die Privilegierten entscheiden wer ein guter Ausländer ist und wer ein schlechter sie überstimmen auch Wissenschaft und Forschung Klimakatastrophe Pandemie Wer die Macht hat dem gehört die Wirklichkeit', 'Den Kern des konservativen Denkens ist eine Art Realitätsfeudalismus Die Privilegierten entscheiden wer ein guter Ausländer ist und wer ein schlechter sie überstimmen auch Wissenschaft und Forschung Klimakatastrophe Pandemie Wer die Macht hat dem gehört die Wirklichkeit']
#
# Thema 9:
# Representation: ['ufoforschung', 'atlantikzirkulation', 'kipppunkt', 'schwarm', 'exeter', 'fantasie', 'tomorrow', 'points', 'regt', 'after']
# Representative_Docs: ['Der Kipppunkt der Atlantikzirkulation regt seit Jahrzehnten die Fantasie an The Day After Tomorrow Der Schwarm usw Doch wo steht die Forschung Hier kurz erklärt bei der Tipping Points Konferenz in Exeter', 'Der Kipppunkt der Atlantikzirkulation regt seit Jahrzehnten die Fantasie an The Day After Tomorrow Der Schwarm usw Doch wo steht die Forschung Hier kurz erklärt bei der Tipping Points Konferenz in Exeter', 'Der Kipppunkt der Atlantikzirkulation regt seit Jahrzehnten die Fantasie an The Day After Tomorrow Der Schwarm usw Doch wo steht die Forschung Hier kurz erklärt bei der Tipping Points Konferenz in Exeter']
#
# Thema 10:
# Representation: ['bildung', 'ministerin', 'bundesministerin', 'schützen', 'starkwatzinger', 'freiheit', 'geschlossen', 'schuljahr', 'unverfroren', 'lügt']
# Representative_Docs: ['K Hallo Fr StarkWatzinger haben Sie das so gesagt Tage waren Schulen geschlossen Ein Schuljahr Das darf nie wieder passieren Wenn ja dann würde das ja bedeuten dass die Bundesministerin für Bildung und Forschung von der FDP unverfroren lügt', 'K Hallo Fr StarkWatzinger haben Sie das so gesagt Tage waren Schulen geschlossen Ein Schuljahr Das darf nie wieder passieren Wenn ja dann würde das ja bedeuten dass die Bundesministerin für Bildung und Forschung von der FDP unverfroren lügt', 'K Hallo Fr StarkWatzinger haben Sie das so gesagt Tage waren Schulen geschlossen Ein Schuljahr Das darf nie wieder passieren Wenn ja dann würde das ja bedeuten dass die Bundesministerin für Bildung und Forschung von der FDP unverfroren lügt']

# %%
len(docs)
# Out:
# 21965

# %%
model.visualize_barchart(top_n_topics = 10, n_words = 5)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="7f8797f4-8b14-48c6-a7b1-eed37ceda9b7" class="plotly-graph-div" style="height:750px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7f8797f4-8b14-48c6-a7b1-eed37ceda9b7")) {                    Plotly.newPlot(                        "7f8797f4-8b14-48c6-a7b1-eed37ceda9b7",                        [{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.013166590439993724,0.014422780787461538,0.017726581718118133,0.020443814424065253,0.026200923426832907],"y":["m\u00fcssen  ","klima  ","china  ","geht  ","forschung  "],"type":"bar","xaxis":"x","yaxis":"y"},{"marker":{"color":"#0072B2"},"orientation":"h","x":[0.020494312494089333,0.020788758758959622,0.023882483771570085,0.029250056210431755,0.03515128962367861],"y":["versorgung  ","mecfsimbundestag  ","forschung  ","longcovid  ","mecfs  "],"type":"bar","xaxis":"x2","yaxis":"y2"},{"marker":{"color":"#CC79A7"},"orientation":"h","x":[0.06823947254513177,0.06843138029660857,0.07050734570138678,0.0718910385421909,0.08374429897570182],"y":["l\u00f6schungen  ","malone  ","pfizers  ","enth\u00fcllungen  ","pfizer  "],"type":"bar","xaxis":"x3","yaxis":"y3"},{"marker":{"color":"#E69F00"},"orientation":"h","x":[0.09331813027097058,0.09487539660108706,0.10326759321991448,0.10853500736320715,0.10983222805051479],"y":["amt  ","widmen  ","dankewieler  ","lothar  ","wieler  "],"type":"bar","xaxis":"x4","yaxis":"y4"},{"marker":{"color":"#56B4E9"},"orientation":"h","x":[0.045264936289157974,0.045264936289157974,0.045797040099698934,0.05268680485060448,0.05310008982301122],"y":["quem  ","est\u00e1  ","nichtgenesen  ","protest  ","berlin  "],"type":"bar","xaxis":"x5","yaxis":"y5"},{"marker":{"color":"#009E73"},"orientation":"h","x":[0.06480409861915551,0.06480409861915551,0.06480409861915551,0.0704104387657902,0.09884599403470944],"y":["t\u00f6teten  ","verhinderten  ","gesamtsterblichkeit  ","zahl  ","cannabis  "],"type":"bar","xaxis":"x6","yaxis":"y6"},{"marker":{"color":"#F0E442"},"orientation":"h","x":[0.05199436827909544,0.052160923587904806,0.05619000471040182,0.059001701962919456,0.08119752016455878],"y":["cn  ","transfeindlichkeit  ","gender  ","selbstbestimmungsgesetz  ","frauen  "],"type":"bar","xaxis":"x7","yaxis":"y7"},{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.07124090901419114,0.07418155065361226,0.0782685087604967,0.08747645976148176,0.107707908569244],"y":["realit\u00e4tsfeudalismus  ","eskalationen  ","lobbyismus  ","demokratie  ","wer  "],"type":"bar","xaxis":"x8","yaxis":"y8"},{"marker":{"color":"#0072B2"},"orientation":"h","x":[0.059619413266336206,0.059619413266336206,0.059619413266336206,0.059619413266336206,0.081907927272432],"y":["exeter  ","schwarm  ","kipppunkt  ","atlantikzirkulation  ","ufoforschung  "],"type":"bar","xaxis":"x9","yaxis":"y9"},{"marker":{"color":"#CC79A7"},"orientation":"h","x":[0.06301974539880836,0.07444465673368887,0.09699324743897333,0.15770343574334078,0.19675139073914527],"y":["starkwatzinger  ","sch\u00fctzen  ","bundesministerin  ","ministerin  ","bildung  "],"type":"bar","xaxis":"x10","yaxis":"y10"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"c ...

# %%
model.visualize_topics()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="8fc16c78-98a5-4481-a022-99a9dd299c6d" class="plotly-graph-div" style="height:650px; width:650px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8fc16c78-98a5-4481-a022-99a9dd299c6d")) {                    Plotly.newPlot(                        "8fc16c78-98a5-4481-a022-99a9dd299c6d",                        [{"customdata":[[0,"forschung | geht | china | klima | m\u00fcssen",6365],[1,"mecfs | longcovid | forschung | mecfsimbundestag | versorgung",5226],[2,"pfizer | enth\u00fcllungen | pfizers | malone | l\u00f6schungen",1232],[3,"wieler | lothar | dankewieler | widmen | amt",872],[4,"berlin | protest | nichtgenesen | est\u00e1 | quem",574],[5,"cannabis | zahl | gesamtsterblichkeit | verhinderten | t\u00f6teten",358],[6,"frauen | selbstbestimmungsgesetz | gender | transfeindlichkeit | cn",312],[7,"wer | demokratie | lobbyismus | eskalationen | realit\u00e4tsfeudalismus",214],[8,"ufoforschung | atlantikzirkulation | kipppunkt | schwarm | exeter",209],[9,"bildung | ministerin | bundesministerin | sch\u00fctzen | starkwatzinger",186],[10,"herr | k\u00e4the | steinmeier | leichterstaatspreis | j\u00fcdin",185],[11,"weihnachten | longcovid | konfidenzintervall | geformte | severe",146],[12,"allgemeinen | w\u00fcrttemberg | k\u00fcrzungen | gek\u00fcrzt | energiekosten",135],[13,"vielleicht | schon | addendum | mafia | klausmichael",117],[14,"verbot | gainoffunctionforschung | maskenpflicht | fernverkehr | eigentlich",96],[15,"varianten | jahre | netto | pflegestufe | kauft",77],[16,"gef\u00e4lscht | betr\u00fcgerisch | genehmigungen | beh\u00f6rdlichen | erforderliche",68],[17,"startup | ittrends | dsm | ar | vr",64],[18,"alzheimer | demenz | vormittag | berichtete | dementen",48],[19,"ausschlie\u00dflicher | pandemieplanspiel | afrikan | beteiligung | oktober",37],[20,"pokemongo | pok\u00e9mon | go | befristeten | befristete",35],[21,"lrrc | protein | repeatcontaining | weiterzugeben | leucinerich",30],[22,"gebrauchtes | just | gro\u00dfz\u00fcgig | soziales | steuergeld",24],[23,"scheidung | deepstate | sch\u00e4fer | familienministerium | sabotiert",18],[24,"us\u00f6lriese | verdeutlichung | \u00f6lkonzernen | explodiert | rekordgewinn",18],[25,"t\u00fcrkiye | t\u00fcrkische | lokomotivmotor | t\u00fcbitak | biokraftstoffbetrieb",15],[26,"sportler | register | ber\u00fchrung | wenden | todesf\u00e4lle",14],[27,"schlaf | schlafen | forschungsrechner | hero | dreamlab",13],[28,"aktenordner | dicken | mastzellaktivierungserkrankung | klagt | gliederschmerzenx",12]],"hovertemplate":"\u003cb\u003eTopic %{customdata[0]}\u003c\u002fb\u003e\u003cbr\u003e%{customdata[1]}\u003cbr\u003eSize: %{customdata[2]}","legendgroup":"","marker":{"color":"#B0BEC5","size":[6365,5226,1232,872,574,358,312,214,209,186,185,146,135,117,96,77,68,64,48,37,35,30,24,18,18,15,14,13,12],"sizemode":"area","sizeref":3.978125,"symbol":"circle","line":{"color":"DarkSlateGrey","width":2}},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[10.837373733520508,8.416696548461914,10.307098388671875,11.793973922729492,12.175321578979492,8.718515396118164,11.073907852172852,11.155234336853027,10.879772186279297,10.998600959777832,12.489131927490234,9.319461822509766,11.495661735534668,12.425626754760742,10.42686939239502,7.633550643920898,8.320941925048828,12.097060203552246,8.171843528747559,10.956535339355469,9.393139839172363,8.9426908493042,7.4079999923706055,10.924307823181152,11.286321640014648,12.261937141418457,8.66440486907959,8.00318717956543,7.964938163757324],"xaxis":"x","y":[0.695370078086853,8.244688987731934,0.14565061032772064,0.5705638527870178,-0.31366395950317383,8.582255363464355,-0.43784788250923157,0.4861679673194885,0.9561201930046082,1.9775416851043701,-0.547156810760498,10.2459640502 ...

# %%
model.visualize_heatmap()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="bee3293f-26de-4581-bf00-a576524d9290" class="plotly-graph-div" style="height:800px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("bee3293f-26de-4581-bf00-a576524d9290")) {                    Plotly.newPlot(                        "bee3293f-26de-4581-bf00-a576524d9290",                        [{"coloraxis":"coloraxis","name":"0","x":["0_forschung_geht_china","1_mecfs_longcovid_forschung","2_pfizer_enth\u00fcllungen_pfizers","3_wieler_lothar_dankewieler","4_berlin_protest_nichtgenesen","5_cannabis_zahl_gesamtsterb...","6_frauen_selbstbestimmungsg...","7_wer_demokratie_lobbyismus","8_ufoforschung_atlantikzirk...","9_bildung_ministerin_bundes...","10_herr_k\u00e4the_steinmeier","11_weihnachten_longcovid_ko...","12_allgemeinen_w\u00fcrttemberg_...","13_vielleicht_schon_addendum","14_verbot_gainoffunctionfor...","15_varianten_jahre_netto","16_gef\u00e4lscht_betr\u00fcgerisch_g...","17_startup_ittrends_dsm","18_alzheimer_demenz_vormittag","19_ausschlie\u00dflicher_pandemi...","20_pokemongo_pok\u00e9mon_go","21_lrrc_protein_repeatconta...","22_gebrauchtes_just_gro\u00dfz\u00fcgig","23_scheidung_deepstate_sch\u00e4...","24_us\u00f6lriese_verdeutlichung...","25_t\u00fcrkiye_t\u00fcrkische_lokomo...","26_sportler_register_ber\u00fchr...","27_schlaf_schlafen_forschun...","28_aktenordner_dicken_mastz..."],"y":["0_forschung_geht_china","1_mecfs_longcovid_forschung","2_pfizer_enth\u00fcllungen_pfizers","3_wieler_lothar_dankewieler","4_berlin_protest_nichtgenesen","5_cannabis_zahl_gesamtsterb...","6_frauen_selbstbestimmungsg...","7_wer_demokratie_lobbyismus","8_ufoforschung_atlantikzirk...","9_bildung_ministerin_bundes...","10_herr_k\u00e4the_steinmeier","11_weihnachten_longcovid_ko...","12_allgemeinen_w\u00fcrttemberg_...","13_vielleicht_schon_addendum","14_verbot_gainoffunctionfor...","15_varianten_jahre_netto","16_gef\u00e4lscht_betr\u00fcgerisch_g...","17_startup_ittrends_dsm","18_alzheimer_demenz_vormittag","19_ausschlie\u00dflicher_pandemi...","20_pokemongo_pok\u00e9mon_go","21_lrrc_protein_repeatconta...","22_gebrauchtes_just_gro\u00dfz\u00fcgig","23_scheidung_deepstate_sch\u00e4...","24_us\u00f6lriese_verdeutlichung...","25_t\u00fcrkiye_t\u00fcrkische_lokomo...","26_sportler_register_ber\u00fchr...","27_schlaf_schlafen_forschun...","28_aktenordner_dicken_mastz..."],"z":[[0.9999999999999994,0.7951663200998857,0.5687877103003618,0.49004939713877116,0.6574645156844973,0.5995640816631371,0.6599405712751526,0.7148817214161144,0.580195812407074,0.6323574162450045,0.4917904024373796,0.5704549981652687,0.6128068128807643,0.3738999203925414,0.6457979917328127,0.3905796464472193,0.4933003673179569,0.5836537630784491,0.4698442837049274,0.39936819189931044,0.3672102669643958,0.2516899046636609,0.4818391395931882,0.3592064143374305,0.4037901992882105,0.3060118978365667,0.33684395828366387,0.3332589609984332,0.2014005158106244],[0.7951663200998857,0.9999999999999993,0.5422873683131547,0.4153800383962512,0.5608306049410694,0.6305195053592055,0.6195606137804193,0.574593578945034,0.47168250512828125,0.42907140876484684,0.43545466299703395,0.6056885586260554,0.4192541516195873,0.3604860312593319,0.6339942161744335,0.5382119723100647,0.5631662078612395,0.435149181123617,0.5390502545816791,0.36591338310296195,0.37057578804321334,0.49180885062873614,0.34329089524667056,0.33950491407011574,0.23770705071677217,0.16601058161618532,0.42246933523115965,0.38392421414116895,0.4788203620145727],[0.5687877103003618,0.5422873683131547,1.0,0.44303047244713145,0.3391179350199759,0.3243315140877381,0.4554771073959266,0.40404146866888857,0.42446762861844944,0.3214454722095141,0.3676301852368873,0.284466561951047,0.28006078529807954,0.27170940830060486,0.5774342391824537,0.21169284703826297,0.49535679311 ...

# %% [markdown]
# #### Themen nach Tweet-Kategorie

# %%
topics_per_class = model.topics_per_class(docs,
    classes=df.tweet_class)
# Out:
# 3it [00:01,  1.82it/s]

# %%
pd.set_option('display.max_rows', 100)
pd.set_option('display.max_columns', 100)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', 100)

# %%
topics_per_class
# Out:
#     Topic                                                                          Words  \
# 0      -1                                        forschung, ja, gibt, mehr, wissenschaft
# 1       0                                               forschung, geht, mehr, china, ja
# 2       1                                 forschung, mecfs, longcovid, covid, versorgung
# 3       2                                    pfizer, enthüllungen, gain, pfizers, malone
# 4       3                                     wieler, lothar, widmen, lehre, dankewieler
# 5       4                        archäologie, nachrichten, kultur, meldungen, geschichte
# 6       5                              cannabis, krebs, krebsforschung, zahl, krebstoten
# 7       6                      frauen, trans, gender, forschung, selbstbestimmungsgesetz
# 8       7                      demokratie, wer, rechte, rechtsextreme, keingeldfürdieafd
# 9       8                          ufoforschung, update, ifouniversität, ballons, arktis
# 10      9                    bildung, ministerin, bundesministerin, verfassung, freiheit
# 11     10                herr, steinmeier, josephgöbbels, mitgründer, weltöffentlichkeit
# 12     11                                 weihnachten, longcovid, bett, jahr, verbringen
# 13     12                               autos, allgemeinen, auto, württemberg, kürzungen
# 14     13                    vielleicht, schon, klugscheissermodus, weiterhelfen, lösung
# 15     14     verbot, gainoffunctionforschung, offiziell, abendspaziergang, verschneiten
# 16     15                                     jahre, netto, senioren, rollstuhl, schicht
# 17     17                  roboter, startup, roboterforschung, verschütteten, kiezblocks
# 18     18                       alzheimer, demenz, alzheimerforschung, lecanemab, bochum
# 19     20                                      pokemongo, pokémon, go, befristete, shiny
# 20     21                        lrrc, myokarditis, spikeproteine, jugendlichen, protein
# 21     22               gebrauchtes, großzügig, steuergeld, soziales, leistungsempfänger
# 22     23                  scheidung, schäfer, deepstate, familienministerium, sabotiert
# 23     24                     verseucht, wieviel, ölkonzernen, verdeutlichung, usölriese
# 24     25     wasserstoffmotoren, türkiye, lokomotivmotor, biokraftstoffbetrieb, tübitak
# 25     27                                        schlaf, schlafen, tipps, eltern, gesund
# 26     28  aktenordner, dicken, mastzellaktivierungserkrankung, klagt, gliederschmerzenx
# 27     -1                                     forschung, gibt, mehr, mecfs, wissenschaft
# 28      0                                          forschung, geht, china, klima, müssen
# 29      1                      mecfs, longcovid, forschung, mecfsimbundestag, versorgung
# 30      2                             pfizer, enthüllungen, pfizers, malone, mrnapionier
# 31      3                                       lothar, wieler, dankewieler, widmen, amt
# 32      4                                      protest, berlin, está, quem, nichtgenesen
# 33      5                       cannabis, zahl, krebstoten, töteten, gesamtsterblichkeit
# 34      6                frauen, selbstbestimmungsgesetz, gender, transfeindlichkeit, cn
# 35      7                wer, lobbyismus, demokratie, eskalationen, realitätsfeudalismus
# 36      8                      kipppunkt, schwarm, exeter, atlantikzirkulation, tomorrow
# 37      9                bildung, ministerin, bundesministerin, schützen, starkwatzinger
# 38     10                           käthe, leichterstaatspreis, jüdin, schafft, leichter
# 39     11                  weihnachten, longcovid, konfidenzintervall, geformte, schenke
# 40     12                              württemberg, kürzungen, allgemeinen, gekürzt, bad
# 41     13                          braumann, addendum, mafia, klausmichael, riffreporter
# 42     14        verbot, gainoffunctionforschung, fernverkehr, eigentlich, maskenpflicht
# 43     15                                  varianten, jahre, netto, pflegestufe, rehaauf
# 44     16            gefälscht, betrügerisch, genehmigungen, behördlichen, erforderliche
# 45     17                                           ittrends, ar, vr, stuttgart, startup
# 46     18                             alzheimer, demenz, vormittag, berichtete, dementen
# 47     19             ausschließlicher, afrikan, pandemieplanspiel, beteiligung, oktober
# 48     20                    pokemongo, befristeten, meisterwerkforschung, jirachi, shop
# 49     21                    lrrc, protein, leucinerich, weiterzugeben, repeatcontaining
# 50     22     just, promotionsstipendien, transformation, graduiertenkolleg, eingebettet
# 51     23  scheidung, geschäftsstelle, dji, familienberichts, sachverständigenkommission
# 52     24                 ölkonzernen, verdeutlichung, usölriese, explodiert, jährlichen
# 53     25              türkische, biokraftstoffbetrieb, tübitak, lokomotivmotor, türkiye
# 54     26                              sportler, register, berührung, wenden, todesfälle
# 55     27                                 schlaf, schlafen, ladekabel, hero, rechenpower
# 56     28  aktenordner, dicken, mastzellaktivierungserkrankung, klagt, gliederschmerzenx
# 57     -1                                                 forschung, mehr, gibt, ja, the
# 58      0                                       forschung, geht, china, kernfusion, mehr
# 59      1                           mecfs, longcovid, forschung, mecfsimbundestag, covid
# 60      2                         malone, derailing, löschungen, holprige, sonntagskrimi
# 61      3                                       wieler, dankewieler, lothar, widmen, rki
# 62      4                             berlin, protest, nichtgenesen, symbolisch, stiller
# 63      5                     cannabis, legalisierung, cannabislegalisierung, zahl, hanf
# 64      6                frauen, selbstbestimmungsgesetz, transfeindlichkeit, cn, gender
# 65      7                        demokratie, lobbyismus, wer, gefährdet, machtergreifung
# 66      8                    exoplanet, erklärt, atlantikzirkulation, kipppunkt, schwarm
# 67      9                               bildung, schützen, ministerin, freiheit, männern
# 68     10                             herr, steinmeier, mitgründer, josephgöbbels, biden
# 69     11                   weihnachten, kempten, modernität, kraftvoll, allgäumetropole
# 70     12                    niedriger, mobilität, energiekosten, württemberg, kürzungen
# 71     13                           nachgeholt, humor, nickerchenforschung, stirbt, gehe
# 72     14             verbot, maskenpflicht, gainoffunctionforschung, fernverkehr, endet
# 73     15                     senioren, eignungsprüfung, varianten, pflegestufe, rehaauf
# 74     16            gefälscht, betrügerisch, genehmigungen, behördlichen, erforderliche
# 75     17                           dsm, startup, trendstudie, pwc, unternehmensgründung
# 76     18                                           alzheimer, cannabis, ecs, study, the
# 77     20                                    pokemongo, pokémon, befristeten, ticket, go
# 78     21            jugendlichen, myokarditis, impfbedingte, ungebundene, spikeproteine
# 79     26                              sportler, register, berührung, wenden, todesfälle
# 80     27                 schlaf, lmuchronobiologen, leistungsfähigkeit, gymnasium, nähe
# 81     28               mcas, aktenordner, dicken, mastzellaktivierungserkrankung, klagt
#
#     Frequency        Class                                         Name
# 0        2877        tweet                    -1_forschung_gibt_mehr_ja
# 1        2245        tweet                 0_forschung_geht_china_klima
# 2        1014        tweet  1_mecfs_longcovid_forschung_mecfsimbunde...
# 3          49        tweet         2_pfizer_enthüllungen_pfizers_malone
# 4          78        tweet           3_wieler_lothar_dankewieler_widmen
# 5         190        tweet           4_berlin_protest_nichtgenesen_está
# 6          75        tweet  5_cannabis_zahl_gesamtsterblichkeit_verh...
# 7          87        tweet  6_frauen_selbstbestimmungsgesetz_gender_...
# 8          32        tweet     7_wer_demokratie_lobbyismus_eskalationen
# 9          99        tweet  8_ufoforschung_atlantikzirkulation_kippp...
# 10         34        tweet  9_bildung_ministerin_bundesministerin_sc...
# 11         11        tweet  10_herr_käthe_steinmeier_leichterstaatsp...
# 12         16        tweet  11_weihnachten_longcovid_konfidenzinterv...
# 13         56        tweet  12_allgemeinen_württemberg_kürzungen_gek...
# 14         93        tweet           13_vielleicht_schon_addendum_mafia
# 15          5        tweet  14_verbot_gainoffunctionforschung_masken...
# 16          6        tweet         15_varianten_jahre_netto_pflegestufe
# 17         19        tweet                   17_startup_ittrends_dsm_ar
# 18         12        tweet     18_alzheimer_demenz_vormittag_berichtete
# 19         29        tweet          20_pokemongo_pokémon_go_befristeten
# 20          7        tweet  21_lrrc_protein_repeatcontaining_weiterz...
# 21         14        tweet       22_gebrauchtes_just_großzügig_soziales
# 22         15        tweet  23_scheidung_deepstate_schäfer_familienm...
# 23          2        tweet  24_usölriese_verdeutlichung_ölkonzernen_...
# 24          4        tweet  25_türkiye_türkische_lokomotivmotor_tübi...
# 25          6        tweet  27_schlaf_schlafen_forschungsrechner_her...
# 26          1        tweet  28_aktenordner_dicken_mastzellaktivierun...
# 27       2012      retweet                    -1_forschung_gibt_mehr_ja
# 28       3662      retweet                 0_forschung_geht_china_klima
# 29       3879      retweet  1_mecfs_longcovid_forschung_mecfsimbunde...
# 30       1113      retweet         2_pfizer_enthüllungen_pfizers_malone
# 31        688      retweet           3_wieler_lothar_dankewieler_widmen
# 32        348      retweet           4_berlin_protest_nichtgenesen_está
# 33        268      retweet  5_cannabis_zahl_gesamtsterblichkeit_verh...
# 34        199      retweet  6_frauen_selbstbestimmungsgesetz_gender_...
# 35        165      retweet     7_wer_demokratie_lobbyismus_eskalationen
# 36        100      retweet  8_ufoforschung_atlantikzirkulation_kippp...
# 37        134      retweet  9_bildung_ministerin_bundesministerin_sc...
# 38         92      retweet  10_herr_käthe_steinmeier_leichterstaatsp...
# 39        124      retweet  11_weihnachten_longcovid_konfidenzinterv...
# 40         63      retweet  12_allgemeinen_württemberg_kürzungen_gek...
# 41         21      retweet           13_vielleicht_schon_addendum_mafia
# 42         82      retweet  14_verbot_gainoffunctionforschung_masken...
# 43         67      retweet         15_varianten_jahre_netto_pflegestufe
# 44         66      retweet  16_gefälscht_betrügerisch_genehmigungen_...
# 45         40      retweet                   17_startup_ittrends_dsm_ar
# 46         33      retweet     18_alzheimer_demenz_vormittag_berichtete
# 47         37      retweet  19_ausschließlicher_pandemieplanspiel_af...
# 48          3      retweet          20_pokemongo_pokémon_go_befristeten
# 49         22      retweet  21_lrrc_protein_repeatcontaining_weiterz...
# 50         10      retweet       22_gebrauchtes_just_großzügig_soziales
# 51          3      retweet  23_scheidung_deepstate_schäfer_familienm...
# 52         16      retweet  24_usölriese_verdeutlichung_ölkonzernen_...
# 53         11      retweet  25_türkiye_türkische_lokomotivmotor_tübi...
# 54          9      retweet        26_sportler_register_berührung_wenden
# 55          6      retweet  27_schlaf_schlafen_forschungsrechner_her...
# 56         10      retweet  28_aktenordner_dicken_mastzellaktivierun...
# 57        376  zitat_tweet                    -1_forschung_gibt_mehr_ja
# 58        458  zitat_tweet                 0_forschung_geht_china_klima
# 59        333  zitat_tweet  1_mecfs_longcovid_forschung_mecfsimbunde...
# 60         70  zitat_tweet         2_pfizer_enthüllungen_pfizers_malone
# 61        106  zitat_tweet           3_wieler_lothar_dankewieler_widmen
# 62         36  zitat_tweet           4_berlin_protest_nichtgenesen_está
# 63         15  zitat_tweet  5_cannabis_zahl_gesamtsterblichkeit_verh...
# 64         26  zitat_tweet  6_frauen_selbstbestimmungsgesetz_gender_...
# 65         17  zitat_tweet     7_wer_demokratie_lobbyismus_eskalationen
# 66         10  zitat_tweet  8_ufoforschung_atlantikzirkulation_kippp...
# 67         18  zitat_tweet  9_bildung_ministerin_bundesministerin_sc...
# 68         82  zitat_tweet  10_herr_käthe_steinmeier_leichterstaatsp...
# 69          6  zitat_tweet  11_weihnachten_longcovid_konfidenzinterv...
# 70         16  zitat_tweet  12_allgemeinen_württemberg_kürzungen_gek...
# 71          3  zitat_tweet           13_vielleicht_schon_addendum_mafia
# 72          9  zitat_tweet  14_verbot_gainoffunctionforschung_masken...
# 73          4  zitat_tweet         15_varianten_jahre_netto_pflegestufe
# 74          2  zitat_tweet  16_gefälscht_betrügerisch_genehmigungen_...
# 75          5  zitat_tweet                   17_startup_ittrends_dsm_ar
# 76          3  zitat_tweet     18_alzheimer_demenz_vormittag_berichtete
# 77          3  zitat_tweet          20_pokemongo_pokémon_go_befristeten
# 78          1  zitat_tweet  21_lrrc_protein_repeatcontaining_weiterz...
# 79          5  zitat_tweet        26_sportler_register_berührung_wenden
# 80          1  zitat_tweet  27_schlaf_schlafen_forschungsrechner_her...
# 81          1  zitat_tweet  28_aktenordner_dicken_mastzellaktivierun...

# %%
model.visualize_topics_per_class(topics_per_class,
    top_n_topics=10, normalize_frequency = True)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="c241891c-445c-480d-972c-85e6e0f29f2e" class="plotly-graph-div" style="height:900px; width:1250px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c241891c-445c-480d-972c-85e6e0f29f2e")) {                    Plotly.newPlot(                        "c241891c-445c-480d-972c-85e6e0f29f2e",                        [{"hoverinfo":"text","hovertext":["\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: forschung, geht, mehr, china, ja","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: forschung, geht, china, klima, m\u00fcssen","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: forschung, geht, china, kernfusion, mehr"],"marker":{"color":"#E69F00"},"name":"0_forschung_geht_china_klima","orientation":"h","visible":true,"x":[0.5197088849756465,0.8477389473411214,0.10602524245828333],"y":["tweet","retweet","zitat_tweet"],"type":"bar"},{"hoverinfo":"text","hovertext":["\u003cb\u003eTopic 1\u003c\u002fb\u003e\u003cbr\u003eWords: forschung, mecfs, longcovid, covid, versorgung","\u003cb\u003eTopic 1\u003c\u002fb\u003e\u003cbr\u003eWords: mecfs, longcovid, forschung, mecfsimbundestag, versorgung","\u003cb\u003eTopic 1\u003c\u002fb\u003e\u003cbr\u003eWords: mecfs, longcovid, forschung, mecfsimbundestag, covid"],"marker":{"color":"#56B4E9"},"name":"1_mecfs_longcovid_forschung_mecfsimbunde...","orientation":"h","visible":"legendonly","x":[0.25204138816880095,0.9641701624327209,0.08277098842229855],"y":["tweet","retweet","zitat_tweet"],"type":"bar"},{"hoverinfo":"text","hovertext":["\u003cb\u003eTopic 2\u003c\u002fb\u003e\u003cbr\u003eWords: pfizer, enth\u00fcllungen, gain, pfizers, malone","\u003cb\u003eTopic 2\u003c\u002fb\u003e\u003cbr\u003eWords: pfizer, enth\u00fcllungen, pfizers, malone, mrnapionier","\u003cb\u003eTopic 2\u003c\u002fb\u003e\u003cbr\u003eWords: malone, derailing, l\u00f6schungen, holprige, sonntagskrimi"],"marker":{"color":"#009E73"},"name":"2_pfizer_enth\u00fcllungen_pfizers_malone","orientation":"h","visible":"legendonly","x":[0.04389599118009584,0.9970660853764627,0.06270855882870835],"y":["tweet","retweet","zitat_tweet"],"type":"bar"},{"hoverinfo":"text","hovertext":["\u003cb\u003eTopic 3\u003c\u002fb\u003e\u003cbr\u003eWords: wieler, lothar, widmen, lehre, dankewieler","\u003cb\u003eTopic 3\u003c\u002fb\u003e\u003cbr\u003eWords: lothar, wieler, dankewieler, widmen, amt","\u003cb\u003eTopic 3\u003c\u002fb\u003e\u003cbr\u003eWords: wieler, dankewieler, lothar, widmen, rki"],"marker":{"color":"#F0E442"},"name":"3_wieler_lothar_dankewieler_widmen","orientation":"h","visible":"legendonly","x":[0.11135314953092272,0.982191883041985,0.15132607500356166],"y":["tweet","retweet","zitat_tweet"],"type":"bar"},{"hoverinfo":"text","hovertext":["\u003cb\u003eTopic 4\u003c\u002fb\u003e\u003cbr\u003eWords: arch\u00e4ologie, nachrichten, kultur, meldungen, geschichte","\u003cb\u003eTopic 4\u003c\u002fb\u003e\u003cbr\u003eWords: protest, berlin, est\u00e1, quem, nichtgenesen","\u003cb\u003eTopic 4\u003c\u002fb\u003e\u003cbr\u003eWords: berlin, protest, nichtgenesen, symbolisch, stiller"],"marker":{"color":"#D55E00"},"name":"4_berlin_protest_nichtgenesen_est\u00e1","orientation":"h","visible":"legendonly","x":[0.47724234133816185,0.8741070251877912,0.09042486467459909],"y":["tweet","retweet","zitat_tweet"],"type":"bar"},{"hoverinfo":"text","hovertext":["\u003cb\u003eTopic 5\u003c\u002fb\u003e\u003cbr\u003eWords: cannabis, krebs, krebsforschung, zahl, krebstoten","\u003cb\u003eTopic 5\u003c\u002fb\u003e\u003cbr\u003eWords: cannabis, zahl, krebstoten, t\u00f6teten, gesamtsterblichkeit","\u003cb\u003eTopic 5\u003c\u002fb\u003e\u003cbr\u003eWords: cannabis, legalisierung, cannabislegalisierung, zahl, hanf"],"marker":{"color":"#0072B2"},"name":"5_cannabis_zahl_gesamt ...
